# %%
import requests
import json
import os
from dotenv import load_dotenv
from pulsefire.clients import RiotAPIClient

load_dotenv()

API_KEY = os.getenv('RIOTAPI')
MISTRAL_KEY = os.getenv('MISTRAL_KEY')
REGION = "na1"

# %%
async with RiotAPIClient(default_headers={"X-Riot-Token": API_KEY}) as client: 
    account = await client.get_account_v1_by_riot_id(region='americas',
                                                    game_name='LukePhysicist',
                                                    tag_line='NA1')
    matches = await client.get_lol_match_v5_match_ids_by_puuid(region='americas',
                                                               puuid=account['puuid'],
                                                               queries = {'start':0, 'count':20})
    league_match = await client.get_lol_match_v5_match(region='americas',
                                                 id=matches[0])
    match_timeline = await client.get_lol_match_v5_match_timeline(region='americas', id=matches[16])
print(json.dumps(account,indent=4))
print(json.dumps(matches,indent=4))
# Out:
# {
#     "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#     "gameName": "LukePhysicist",
#     "tagLine": "NA1"
# }
# [
#     "NA1_5227964890",
#     "NA1_5223256507",
#     "NA1_5223227844",
#     "NA1_5223007331",
#     "NA1_5223000023",
#     "NA1_5222347760",
#     "NA1_5221714012",
#     "NA1_5220554885",
#     "NA1_5220527537",
#     "NA1_5220515974",
#     "NA1_5220475725",
#     "NA1_5220180563",
#     "NA1_5220156418",
#     "NA1_5220135361",
#     "NA1_5220113681",
#     "NA1_5219727342",
#     "NA1_5219664701",
#     "NA1_5219629624",
#     "NA1_5218766856",
#     "NA1_5218740710"
# ]

# %%
print(json.dumps(league_match,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5227964890",
#         "participants": [
#             "bke3Fz9l6T1cqZb7PgzLbj8CJy9r6OQo10LCdwYwoovS0jisYm2RXQMTGzOQv5RAT5YPZCUZTHs44g",
#             "dQMesHv6J1lskYe6Qdl8vd2Gt4ptwBi21AU0ml6qhaEA6bT7ncIS2S3FTdwGHXBmSgihQPLEbmgVqg",
#             "Vfk1HbA9b8WbRUj2vBeXwm__DYpCeamMM6vShYOzmFymOidSwlskGcPfrLniOekc5p9GQjJhySNoHg",
#             "XB_Ul_SbicH0wbrGw1qms6MqXa8YGfEB_yONqA4uIikyQkui2BnWUp0uXaLe08kjrz3oADhIQhJXHA",
#             "OJLIiyRFokcu7pcqKsp_Vu6UhAIV8O0hrKFNjfS6THvuDicP6SS8bjyzogu6qTOsqjpuMpJgtazkEA",
#             "nEWwhwr82sDUXTLAaBvCZQ8sBASk05bEcP7I8uzsDBGtp07lAzcoZdOLSIEq2CjNlIE39ZK3C8bR7w",
#             "9S4YJbEWGLsX0udpPPYzEgMdJVdNIkkXGqp6X8kthOVlWuuN9zAXutyD-TBT1Im7Zmd2DxmELsJjCA",
#             "LlnbW45BBQEzlfe0nYpHNFPo1wFeeeW9rf7cLTotxyQCYAWtV899GxhwYPVb6Ch0nqW28_TN5tcnAw",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "IjVV-Hb_jUGDy2fvb-47aophl25YxD6LYr_RD4yXqrlCyYbl7yGIP_UBR8uz0-y6P0IaKujv9itXbg"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "gameCreation": 1739382613550,
#         "gameDuration": 2003,
#         "gameEndTimestamp": 1739384646430,
#         "gameId": 5227964890,
#         "gameMode": "CLASSIC",
#         "gameName": "teambuilder-match-5227964890",
#         "gameStartTimestamp": 1739382642588,
#         "gameType": "MATCHED_GAME",
#         "gameVersion": "15.3.654.407",
#         "mapId": 11,
#         "participants": [
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 0,
#                 "assists": 15,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 7,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 552.3144073486328,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 222,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 1254.0404521116309,
#                     "damageTakenOnTeamPercentage": 0.22982065334783586,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 3,
#                     "dodgeSkillShotsSmallWindow": 2,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 3,
#                     "earliestBaron": 1735.238871723,
#                     "earliestDragonTakedown": 1179.7553937090001,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 52,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 1,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 4,
#                     "gameLength": 2004.0984040970002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 455.5055322084204,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 6,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 7.333333333333333,
#                     "killAfterHiddenWithAlly": 1,
#                     "killParticipation": 0.5116279069767442,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 1,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 1,
#                     "killsWithHelpFromEpicMonster": 2,
#                     "knockEnemyIntoTeamAndKill": 7,
#                     "landSkillShotsEarlyGame": 11,
#                     "laneMinionsFirst10Minutes": 65,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3078,
#                         3071,
#                         3091,
#                         3075
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 24,
#                     "maxKillDeficit": 2,
#                     "maxLevelLeadLaneOpponent": 3,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 1,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 11,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 1,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 1,
#                     "shortestTimeToAceFromFirstTakedown": 12.928287087999934,
#                     "skillshotsDodged": 35,
#                     "skillshotsHit": 57,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 3,
#                     "stealthWardsPlaced": 11,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 1,
#                     "takedowns": 22,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 8,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 1,
#                     "teamDamagePercentage": 0.29147023463674443,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 1,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 3,
#                     "turretTakedowns": 8,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.3626279830932617,
#                     "visionScorePerMinute": 0.7953983045540944,
#                     "voidMonsterKill": 2,
#                     "wardTakedowns": 4,
#                     "wardTakedownsBefore20M": 1,
#                     "wardsGuarded": 5
#                 },
#                 "champExperience": 20131,
#                 "champLevel": 18,
#                 "championId": 150,
#                 "championName": "Gnar",
#                 "championTransform": 0,
#                 "commandPings": 9,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 11707,
#                 "damageDealtToObjectives": 34924,
#                 "damageDealtToTurrets": 11707,
#                 "damageSelfMitigated": 30187,
#                 "dangerPings": 0,
#                 "deaths": 3,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 1,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 2,
#                 "enemyVisionPings": 1,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 0,
#                 "goldEarned": 15214,
#                 "goldSpent": 14033,
#                 "holdPings": 0,
#                 "individualPosition": "TOP",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 2,
#                 "inhibitorsLost": 0,
#                 "item0": 3078,
#                 "item1": 3071,
#                 "item2": 3091,
#                 "item3": 3111,
#                 "item4": 3075,
#                 "item5": 1055,
#                 "item6": 3340,
#                 "itemsPurchased": 24,
#                 "killingSprees": 2,
#                 "kills": 7,
#                 "lane": "TOP",
#                 "largestCriticalStrike": 18,
#                 "largestKillingSpree": 4,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 1178,
#                 "magicDamageDealt": 30588,
#                 "magicDamageDealtToChampions": 11615,
#                 "magicDamageTaken": 15417,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 8,
#                 "nexusKills": 1,
#                 "nexusLost": 0,
#                 "nexusTakedowns": 1,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 7,
#                 "participantId": 1,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8437,
#                                     "var1": 1105,
#                                     "var2": 625,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8446,
#                                     "var1": 4548,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8473,
#                                     "var1": 1166,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8451,
#                                     "var1": 298,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 9111,
#                                     "var1": 2546,
#                                     "var2": 440,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9104,
#                                     "var1": 12,
#                                     "var2": 10,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 187314,
#                 "physicalDamageDealtToChampions": 29833,
#                 "physicalDamageTaken": 17862,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6052,
#                 "pushPings": 0,
#                 "puuid": "bke3Fz9l6T1cqZb7PgzLbj8CJy9r6OQo10LCdwYwoovS0jisYm2RXQMTGzOQv5RAT5YPZCUZTHs44g",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "DoctorDinoNinja",
#                 "riotIdTagline": "TTV",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 151,
#                 "spell2Casts": 24,
#                 "spell3Casts": 34,
#                 "spell4Casts": 13,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 5,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 3,
#                 "summoner2Id": 12,
#                 "summonerId": "mtBcVT6BH_Zapmc1fnUKECcnHEyEyk5VSJHf0Swb38S-fZs",
#                 "summonerLevel": 717,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "TOP",
#                 "timeCCingOthers": 46,
#                 "timePlayed": 2003,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 224303,
#                 "totalDamageDealtToChampions": 41887,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 34305,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 8455,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 225,
#                 "totalTimeCCDealt": 531,
#                 "totalTimeSpentDead": 74,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 6400,
#                 "trueDamageDealtToChampions": 437,
#                 "trueDamageTaken": 1025,
#                 "turretKills": 2,
#                 "turretTakedowns": 8,
#                 "turretsLost": 2,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 26,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 4,
#                 "wardsPlaced": 11,
#                 "win": true
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 1,
#                 "assists": 16,
#                 "baronKills": 1,
#                 "basicPings": 0,
#                 "bountyLevel": 12,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 986.8355178833008,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 222,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 1,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 12,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardTimeCoverageInRiverOrEnemyHalf": 0.5518303610666777,
#                     "controlWardsPlaced": 1,
#                     "damagePerMinute": 663.3660391100004,
#                     "damageTakenOnTeamPercentage": 0.28109749272594303,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 2,
#                     "dodgeSkillShotsSmallWindow": 2,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 2,
#                     "earliestBaron": 1735.238871723,
#                     "earliestDragonTakedown": 1568.900139994,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 10,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 2,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 1,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 4,
#                     "gameLength": 2004.0984040970002,
#                     "goldPerMinute": 481.019664611659,
#                     "hadOpenNexus": 0,
#                     "highestCrowdControlScore": 1,
#                     "immobilizeAndKillWithAlly": 9,
#                     "initialBuffCount": 2,
#                     "initialCrabCount": 1,
#                     "jungleCsBefore10Minutes": 60.000000059604645,
#                     "junglerKillsEarlyJungle": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 14,
#                     "killAfterHiddenWithAlly": 4,
#                     "killParticipation": 0.6511627906976745,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 3,
#                     "killsNearEnemyTurret": 2,
#                     "killsOnLanersEarlyJungleAsJungler": 2,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 2,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 6,
#                     "laneMinionsFirst10Minutes": 8,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         6631,
#                         3073,
#                         3071,
#                         6333
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 6.500000029802322,
#                     "maxKillDeficit": 2,
#                     "maxLevelLeadLaneOpponent": 3,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 2,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 3,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 19,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 1,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 4,
#                     "shortestTimeToAceFromFirstTakedown": 12.928287087999934,
#                     "skillshotsDodged": 38,
#                     "skillshotsHit": 32,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 1,
#                     "soloTurretsLategame": 1,
#                     "stealthWardsPlaced": 4,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 28,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 7,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 1,
#                     "teamDamagePercentage": 0.15418278951357786,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 1,
#                     "tookLargeDamageSurvived": 1,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 4,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.03094959259033203,
#                     "visionScorePerMinute": 0.6152169572836749,
#                     "voidMonsterKill": 7,
#                     "wardTakedowns": 4,
#                     "wardTakedownsBefore20M": 1,
#                     "wardsGuarded": 2
#                 },
#                 "champExperience": 20025,
#                 "champLevel": 18,
#                 "championId": 56,
#                 "championName": "Nocturne",
#                 "championTransform": 0,
#                 "commandPings": 15,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 3618,
#                 "damageDealtToObjectives": 41168,
#                 "damageDealtToTurrets": 3618,
#                 "damageSelfMitigated": 31885,
#                 "dangerPings": 0,
#                 "deaths": 2,
#                 "detectorWardsPlaced": 1,
#                 "doubleKills": 2,
#                 "dragonKills": 2,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 1,
#                 "enemyVisionPings": 0,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 29,
#                 "goldEarned": 16066,
#                 "goldSpent": 15712,
#                 "holdPings": 0,
#                 "individualPosition": "JUNGLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 2,
#                 "inhibitorsLost": 0,
#                 "item0": 3073,
#                 "item1": 3071,
#                 "item2": 6631,
#                 "item3": 3047,
#                 "item4": 6333,
#                 "item5": 2020,
#                 "item6": 3364,
#                 "itemsPurchased": 33,
#                 "killingSprees": 3,
#                 "kills": 12,
#                 "lane": "JUNGLE",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 5,
#                 "largestMultiKill": 2,
#                 "longestTimeSpentLiving": 616,
#                 "magicDamageDealt": 5066,
#                 "magicDamageDealtToChampions": 1620,
#                 "magicDamageTaken": 12026,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 199,
#                 "nexusKills": 0,
#                 "nexusLost": 0,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 20,
#                 "participantId": 2,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8008,
#                                     "var1": 209,
#                                     "var2": 209,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9111,
#                                     "var1": 3421,
#                                     "var2": 560,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9104,
#                                     "var1": 11,
#                                     "var2": 50,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8014,
#                                     "var1": 681,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8143,
#                                     "var1": 516,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8106,
#                                     "var1": 5,
#                                     "var2": 31,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8100
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 244986,
#                 "physicalDamageDealtToChampions": 19464,
#                 "physicalDamageTaken": 25784,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6641,
#                 "pushPings": 0,
#                 "puuid": "dQMesHv6J1lskYe6Qdl8vd2Gt4ptwBi21AU0ml6qhaEA6bT7ncIS2S3FTdwGHXBmSgihQPLEbmgVqg",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "alwn",
#                 "riotIdTagline": "2420",
#                 "role": "NONE",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 134,
#                 "spell2Casts": 14,
#                 "spell3Casts": 52,
#                 "spell4Casts": 22,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 3,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 14,
#                 "summoner2Id": 11,
#                 "summonerId": "328P3_xwjOOZs22VoNpLyiMT0V7K-LbAP3MhP10WKM8TUek",
#                 "summonerLevel": 584,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "JUNGLE",
#                 "timeCCingOthers": 163,
#                 "timePlayed": 2003,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 326482,
#                 "totalDamageDealtToChampions": 22157,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 41960,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 24806,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 50,
#                 "totalTimeCCDealt": 705,
#                 "totalTimeSpentDead": 52,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 76429,
#                 "trueDamageDealtToChampions": 1072,
#                 "trueDamageTaken": 4148,
#                 "turretKills": 2,
#                 "turretTakedowns": 4,
#                 "turretsLost": 2,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 20,
#                 "visionWardsBoughtInGame": 1,
#                 "wardsKilled": 4,
#                 "wardsPlaced": 5,
#                 "win": true
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 3,
#                 "assists": 11,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 17,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 439,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 1,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 1321.0480618554786,
#                     "damageTakenOnTeamPercentage": 0.09907665626233254,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 0,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earliestBaron": 1735.238871723,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 87,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "fastestLegendary": 1385.0769589220001,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 4,
#                     "gameLength": 2004.0984040970002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 510.64466013514544,
#                     "hadOpenNexus": 0,
#                     "highestChampionDamage": 1,
#                     "immobilizeAndKillWithAlly": 7,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 2,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 28,
#                     "killAfterHiddenWithAlly": 2,
#                     "killParticipation": 0.6511627906976745,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 1,
#                     "killsNearEnemyTurret": 2,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 3,
#                     "knockEnemyIntoTeamAndKill": 7,
#                     "landSkillShotsEarlyGame": 4,
#                     "laneMinionsFirst10Minutes": 82,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 1,
#                     "legendaryItemUsed": [
#                         6655,
#                         4646,
#                         3089,
#                         3041,
#                         3135
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 24,
#                     "maxKillDeficit": 2,
#                     "maxLevelLeadLaneOpponent": 3,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 3,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 3,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 18,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "shortestTimeToAceFromFirstTakedown": 12.928287087999934,
#                     "skillshotsDodged": 32,
#                     "skillshotsHit": 82,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 1,
#                     "stealthWardsPlaced": 13,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 28,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 4,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 1,
#                     "teamDamagePercentage": 0.3070444720559598,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 1,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 1,
#                     "turretTakedowns": 5,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.11464536190032959,
#                     "visionScorePerMinute": 0.6486216716939094,
#                     "voidMonsterKill": 1,
#                     "wardTakedowns": 0,
#                     "wardTakedownsBefore20M": 0,
#                     "wardsGuarded": 2
#                 },
#                 "champExperience": 19883,
#                 "champLevel": 18,
#                 "championId": 134,
#                 "championName": "Syndra",
#                 "championTransform": 0,
#                 "commandPings": 9,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 7297,
#                 "damageDealtToObjectives": 12061,
#                 "damageDealtToTurrets": 7297,
#                 "damageSelfMitigated": 7991,
#                 "dangerPings": 0,
#                 "deaths": 0,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 3,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 5,
#                 "enemyVisionPings": 1,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 0,
#                 "goldEarned": 17056,
#                 "goldSpent": 15155,
#                 "holdPings": 0,
#                 "individualPosition": "MIDDLE",
#                 "inhibitorKills": 2,
#                 "inhibitorTakedowns": 2,
#                 "inhibitorsLost": 0,
#                 "item0": 3089,
#                 "item1": 6655,
#                 "item2": 3020,
#                 "item3": 4646,
#                 "item4": 3041,
#                 "item5": 3135,
#                 "item6": 3340,
#                 "itemsPurchased": 20,
#                 "killingSprees": 1,
#                 "kills": 17,
#                 "lane": "MIDDLE",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 17,
#                 "largestMultiKill": 2,
#                 "longestTimeSpentLiving": 0,
#                 "magicDamageDealt": 169738,
#                 "magicDamageDealtToChampions": 38340,
#                 "magicDamageTaken": 9139,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 3,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 0,
#                 "nexusTakedowns": 1,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 12,
#                 "participantId": 3,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8369,
#                                     "var1": 1372,
#                                     "var2": 750,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8304,
#                                     "var1": 11,
#                                     "var2": 1,
#                                     "var3": 5
#                                 },
#                                 {
#                                     "perk": 8345,
#                                     "var1": 3,
#                                     "var2": 0,
#                                     "var3": 393
#                                 },
#                                 {
#                                     "perk": 8347,
#                                     "var1": 0,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8300
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8226,
#                                     "var1": 250,
#                                     "var2": 1024,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8210,
#                                     "var1": 59,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 14156,
#                 "physicalDamageDealtToChampions": 1112,
#                 "physicalDamageTaken": 5505,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 687,
#                 "pushPings": 0,
#                 "puuid": "Vfk1HbA9b8WbRUj2vBeXwm__DYpCeamMM6vShYOzmFymOidSwlskGcPfrLniOekc5p9GQjJhySNoHg",
#                 "quadraKills": 0,
#                 "retreatPings": 4,
#                 "riotIdGameName": "Boosted LeBlanc",
#                 "riotIdTagline": "LB OP",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 171,
#                 "spell2Casts": 207,
#                 "spell3Casts": 52,
#                 "spell4Casts": 9,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 3,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 2,
#                 "summoner2Id": 12,
#                 "summonerId": "8yZDl5sA9FvIH7FNSh2fl1eI-vjBpTTp1XI18_oqszFhAGPwbToNeBIHnA",
#                 "summonerLevel": 321,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "MIDDLE",
#                 "timeCCingOthers": 44,
#                 "timePlayed": 2003,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 193611,
#                 "totalDamageDealtToChampions": 44125,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 14789,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 2397,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 222,
#                 "totalTimeCCDealt": 371,
#                 "totalTimeSpentDead": 0,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 9716,
#                 "trueDamageDealtToChampions": 4671,
#                 "trueDamageTaken": 143,
#                 "turretKills": 4,
#                 "turretTakedowns": 5,
#                 "turretsLost": 2,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 21,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 0,
#                 "wardsPlaced": 13,
#                 "win": true
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 0,
#                 "assists": 7,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 5,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 180,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 1,
# ...
#                     "firstTurretKilledTime": 690.360540841,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 2,
#                     "gameLength": 2004.0984040970002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 232.00539925589425,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 1,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 2,
#                     "killAfterHiddenWithAlly": 2,
#                     "killParticipation": 0.5882352941176471,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 2,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 9,
#                     "laneMinionsFirst10Minutes": 10,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3504,
#                         3870,
#                         6617
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 0,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 2,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 1,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 9,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 2,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 26,
#                     "skillshotsHit": 62,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "stealthWardsPlaced": 32,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 4,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 10,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 5,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.11640850329439192,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 3,
#                     "turretTakedowns": 0,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.3384702205657959,
#                     "visionScorePerMinute": 1.9154710225734968,
#                     "voidMonsterKill": 1,
#                     "wardTakedowns": 2,
#                     "wardTakedownsBefore20M": 1,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 11482,
#                 "champLevel": 14,
#                 "championId": 117,
#                 "championName": "Lulu",
#                 "championTransform": 0,
#                 "commandPings": 10,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 1013,
#                 "damageDealtToObjectives": 5071,
#                 "damageDealtToTurrets": 1013,
#                 "damageSelfMitigated": 9199,
#                 "dangerPings": 0,
#                 "deaths": 5,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 13,
#                 "enemyVisionPings": 0,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 3,
#                 "goldEarned": 7749,
#                 "goldSpent": 7200,
#                 "holdPings": 0,
#                 "individualPosition": "UTILITY",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 3,
#                 "item0": 3870,
#                 "item1": 3504,
#                 "item2": 3158,
#                 "item3": 6617,
#                 "item4": 3067,
#                 "item5": 3114,
#                 "item6": 3364,
#                 "itemsPurchased": 16,
#                 "killingSprees": 1,
#                 "kills": 2,
#                 "lane": "BOTTOM",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 651,
#                 "magicDamageDealt": 25237,
#                 "magicDamageDealtToChampions": 10848,
#                 "magicDamageTaken": 8195,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 35,
#                 "participantId": 10,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5007
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8214,
#                                     "var1": 1020,
#                                     "var2": 1131,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8226,
#                                     "var1": 250,
#                                     "var2": 577,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8210,
#                                     "var1": 4,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8237,
#                                     "var1": 453,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8473,
#                                     "var1": 337,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8453,
#                                     "var1": 519,
#                                     "var2": 1704,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 3712,
#                 "physicalDamageDealtToChampions": 1307,
#                 "physicalDamageTaken": 10440,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6621,
#                 "pushPings": 1,
#                 "puuid": "IjVV-Hb_jUGDy2fvb-47aophl25YxD6LYr_RD4yXqrlCyYbl7yGIP_UBR8uz0-y6P0IaKujv9itXbg",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "d d",
#                 "riotIdTagline": "anna",
#                 "role": "SUPPORT",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 63,
#                 "spell2Casts": 80,
#                 "spell3Casts": 92,
#                 "spell4Casts": 12,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 6,
#                 "summoner1Id": 7,
#                 "summoner2Casts": 5,
#                 "summoner2Id": 4,
#                 "summonerId": "r8AeYqUk0wtuKZxELzqAxJIwzXpZxQ-T9_8EfbxFfzrGIBnxq4sWi9Rctw",
#                 "summonerLevel": 195,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 200,
#                 "teamPosition": "UTILITY",
#                 "timeCCingOthers": 32,
#                 "timePlayed": 2003,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 30428,
#                 "totalDamageDealtToChampions": 12207,
#                 "totalDamageShieldedOnTeammates": 7372,
#                 "totalDamageTaken": 19498,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 3312,
#                 "totalHealsOnTeammates": 899,
#                 "totalMinionsKilled": 17,
#                 "totalTimeCCDealt": 278,
#                 "totalTimeSpentDead": 152,
#                 "totalUnitsHealed": 4,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 1478,
#                 "trueDamageDealtToChampions": 50,
#                 "trueDamageTaken": 861,
#                 "turretKills": 0,
#                 "turretTakedowns": 0,
#                 "turretsLost": 11,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 63,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 2,
#                 "wardsPlaced": 32,
#                 "win": false
#             }
#         ],
#         "platformId": "NA1",
#         "queueId": 420,
#         "teams": [
#             {
#                 "bans": [
#                     {
#                         "championId": 203,
#                         "pickTurn": 1
#                     },
#                     {
#                         "championId": 166,
#                         "pickTurn": 2
#                     },
#                     {
#                         "championId": 29,
#                         "pickTurn": 3
#                     },
#                     {
#                         "championId": 62,
#                         "pickTurn": 4
#                     },
#                     {
#                         "championId": 39,
#                         "pickTurn": 5
#                     }
#                 ],
#                 "objectives": {
#                     "atakhan": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "baron": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "champion": {
#                         "first": false,
#                         "kills": 43
#                     },
#                     "dragon": {
#                         "first": false,
#                         "kills": 3
#                     },
#                     "horde": {
#                         "first": false,
#                         "kills": 4
#                     },
#                     "inhibitor": {
#                         "first": true,
#                         "kills": 3
#                     },
#                     "riftHerald": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "tower": {
#                         "first": false,
#                         "kills": 11
#                     }
#                 },
#                 "teamId": 100,
#                 "win": true
#             },
#             {
#                 "bans": [
#                     {
#                         "championId": 111,
#                         "pickTurn": 6
#                     },
#                     {
#                         "championId": 131,
#                         "pickTurn": 7
#                     },
#                     {
#                         "championId": 238,
#                         "pickTurn": 8
#                     },
#                     {
#                         "championId": 143,
#                         "pickTurn": 9
#                     },
#                     {
#                         "championId": 39,
#                         "pickTurn": 10
#                     }
#                 ],
#                 "objectives": {
#                     "atakhan": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "baron": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "champion": {
#                         "first": true,
#                         "kills": 17
#                     },
#                     "dragon": {
#                         "first": true,
#                         "kills": 2
#                     },
#                     "horde": {
#                         "first": true,
#                         "kills": 2
#                     },
#                     "inhibitor": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "riftHerald": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "tower": {
#                         "first": true,
#                         "kills": 2
#                     }
#                 },
#                 "teamId": 200,
#                 "win": false
#             }
#         ],
#         "tournamentCode": ""
#     }
# }

# %%
print(json.dumps(match_timeline,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5219664701",
#         "participants": [
#             "psIS-jEiD395_Ze7jGUezx-STXKsfgtGEYJxztdc5ii-bA7UQ9k70GMW2anf5dtnwryGziSVJszuxQ",
#             "lrsd6NxJUGdsY8wQ4pkl208cwMWtxdPDc9nmxkMjnYe8PdblQLnaKm4p7uzhPxWD_1rllXwnZ-SIbA",
#             "D9Eq35nDgsihaTtECccCww59bkNWnBddmF0LBfV4dm1i-miFecX3tNK4AI6LtB-moBuKntPQuhj9kA",
#             "WZmqhqzBa35voA3eSKANMmjMP5zt4GFyZz0DLCvt5Omou6Z4vkbyjTV5YEdTJusmAZtuy1GWmwA12A",
#             "hbLouJSQ9Tw_qliI6LjADHit0zC32mGdJWmFPvsuSIrCnfG9rbzx1P_nvnQ5vVTTTppHJ4Tk9jrnWQ",
#             "9MaIkv3NSX8k9sHxIUNWTGOZZQhp5PqkfOYuGnY8vWf_1-LpOiLDTKjNvoDbW8dwgDpcP-V_Sh0oHw",
#             "-TOZutRRUM-3xDPWgKtXkGWxKht2klcGLhMPy4y42Dvwtjunp_DW-T-P_hi8wO-BSNBBaAcE_lrU1w",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "t39gBaAwIVbvXfZw7QZh_XeeeqPWXsVEfheJdvhbye7AcrDTRzhOjM53ABt-85MQjQVQS7-DTogHxA",
#             "KUghYHlmqKjqv-DEixUt7mj8tx0PuDGVZ16C3fQXR2YkHeZyMlV3_Z1YSxOaClzm_-dB4iwOJ-paWA"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "frameInterval": 60000,
#         "frames": [
#             {
#                 "events": [
#                     {
#                         "realTimestamp": 1738381277853,
#                         "timestamp": 0,
#                         "type": "PAUSE_END"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 26,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 670,
#                             "healthMax": 670,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 22,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 330,
#                             "powerMax": 330,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 554,
#                             "y": 581
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 30,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 630,
#                             "healthMax": 630,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 297,
#                             "powerMax": 297,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 593,
#                             "y": 464
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 18,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 550,
#                             "healthMax": 550,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 470,
#                             "powerMax": 470,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 557,
#                             "y": 345
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 24,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 655,
#                             "healthMax": 655,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 300,
#                             "powerMax": 300,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 458,
#                             "y": 271
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 21,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 630,
#                             "healthMax": 630,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 425,
#                             "powerMax": 425,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 5,
#                         "position": {
#                             "x": 335,
#                             "y": 269
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 39,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 650,
#                             "healthMax": 650,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 300,
#                             "powerMax": 300,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 6,
#                         "position": {
#                             "x": 14500,
#                             "y": 14511
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 39,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 652,
#                             "healthMax": 652,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 263,
#                             "powerMax": 263,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 7,
#                         "position": {
#                             "x": 14539,
#                             "y": 14394
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 675,
#                             "healthMax": 675,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 361,
#                             "powerMax": 361,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 8,
#                         "position": {
#                             "x": 14503,
#                             "y": 14275
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 28,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 640,
#                             "healthMax": 640,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 325,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 300,
#                             "powerMax": 300,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 9,
#                         "position": {
#                             "x": 14404,
#                             "y": 14201
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 22,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 590,
#                             "healthMax": 590,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 469,
#                             "powerMax": 469,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 10,
#                         "position": {
#                             "x": 14281,
#                             "y": 14199
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     }
#                 },
#                 "timestamp": 0
#             },
#             {
#                 "events": [
#                     {
#                         "itemId": 1056,
#                         "participantId": 3,
#                         "timestamp": 4229,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 4229,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 4229,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 9,
#                         "timestamp": 5465,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 9,
#                         "timestamp": 5999,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 9,
#                         "timestamp": 6333,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 4,
#                         "timestamp": 8204,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 4,
#                         "timestamp": 8204,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 4,
#                         "timestamp": 8972,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1102,
#                         "participantId": 2,
#                         "timestamp": 11243,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 10,
#                         "timestamp": 11845,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 11845,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 11845,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 5,
#                         "timestamp": 11878,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 2,
#                         "timestamp": 11878,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1054,
#                         "participantId": 6,
#                         "timestamp": 12045,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 6,
#                         "timestamp": 12045,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 10,
#                         "timestamp": 12245,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 12579,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1102,
#                         "participantId": 7,
#                         "timestamp": 12613,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 12713,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 7,
#                         "timestamp": 13114,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 7,
#                         "timestamp": 13348,
#                         "type": "ITEM_DESTROYED"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 7,
#                         "timestamp": 13348,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 7,
#                         "skillSlot": 1,
#                         "timestamp": 16556,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 8,
#                         "timestamp": 17959,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 8,
#                         "timestamp": 17959,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 10,
#                         "skillSlot": 1,
#                         "timestamp": 18026,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 8,
#                         "timestamp": 18360,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 1,
#                         "timestamp": 18827,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 1,
#                         "timestamp": 18827,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 1,
#                         "timestamp": 19161,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 8,
#                         "skillSlot": 1,
#                         "timestamp": 20865,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 4,
#                         "skillSlot": 1,
#                         "timestamp": 21032,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "creatorId": 2,
#                         "timestamp": 37072,
#                         "type": "WARD_PLACED",
#                         "wardType": "YELLOW_TRINKET"
#                     },
#                     {
#                         "killerId": 7,
#                         "timestamp": 41952,
#                         "type": "WARD_KILL",
#                         "wardType": "YELLOW_TRINKET"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 2,
#                         "skillSlot": 2,
#                         "timestamp": 46929,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 9,
#                         "skillSlot": 1,
#                         "timestamp": 49234,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 3,
#                         "skillSlot": 1,
#                         "timestamp": 58720,
#                         "type": "SKILL_LEVEL_UP"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 26,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 65,
#                             "attackSpeed": 113,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 760,
#                             "healthMax": 760,
#                             "healthRegen": 10,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 22,
#                             "movementSpeed": 338,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 330,
#                             "powerMax": 330,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 1419,
#                             "y": 10848
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 30,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 68,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 640,
#                             "healthMax": 640,
#                             "healthRegen": 17,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 256,
#                             "powerMax": 297,
#                             "powerRegen": 27,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 50,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 6894,
#                             "y": 4773
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 27,
#                             "armor": 18,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 58,
#                             "attackSpeed": 110,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 650,
#                             "healthMax": 650,
#                             "healthRegen": 13,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 363,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 470,
#                             "powerMax": 470,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 8314,
#                             "y": 6066
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 24,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 84,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 745,
#                             "healthMax": 745,
#                             "healthRegen": 7,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 300,
#                             "powerMax": 300,
#                             "powerRegen": 12,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 9900,
#                             "y": 2640
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 18,
#                             "armor": 21,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 58,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 725,
#                             "healthMax": 725,
#                             "healthRegen": 18,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 425,
#                             "powerMax": 425,
#                             "powerRegen": 20,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
# ...
#                             "physicalDamageDone": 11991,
#                             "physicalDamageDoneToChampions": 2725,
#                             "physicalDamageTaken": 25892,
#                             "totalDamageDone": 123338,
#                             "totalDamageDoneToChampions": 40002,
#                             "totalDamageTaken": 44863,
#                             "trueDamageDone": 15584,
#                             "trueDamageDoneToChampions": 8780,
#                             "trueDamageTaken": 4000
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 10,
#                         "level": 18,
#                         "minionsKilled": 83,
#                         "participantId": 5,
#                         "position": {
#                             "x": 11339,
#                             "y": 11107
#                         },
#                         "timeEnemySpentControlled": 235766,
#                         "totalGold": 16630,
#                         "xp": 24338
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 223,
#                             "armorPen": 0,
#                             "armorPenPercent": 30,
#                             "attackDamage": 321,
#                             "attackSpeed": 174,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 40,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 5071,
#                             "healthRegen": 86,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 201,
#                             "movementSpeed": 400,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 901,
#                             "powerMax": 1320,
#                             "powerRegen": 40,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1417,
#                         "damageStats": {
#                             "magicDamageDone": 63361,
#                             "magicDamageDoneToChampions": 13016,
#                             "magicDamageTaken": 26277,
#                             "physicalDamageDone": 317148,
#                             "physicalDamageDoneToChampions": 25094,
#                             "physicalDamageTaken": 40255,
#                             "totalDamageDone": 397853,
#                             "totalDamageDoneToChampions": 39065,
#                             "totalDamageTaken": 71958,
#                             "trueDamageDone": 17343,
#                             "trueDamageDoneToChampions": 954,
#                             "trueDamageTaken": 5424
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 32,
#                         "level": 18,
#                         "minionsKilled": 362,
#                         "participantId": 6,
#                         "position": {
#                             "x": 8363,
#                             "y": 5303
#                         },
#                         "timeEnemySpentControlled": 411143,
#                         "totalGold": 22809,
#                         "xp": 31194
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 280,
#                             "armorPen": 0,
#                             "armorPenPercent": 39,
#                             "attackDamage": 300,
#                             "attackSpeed": 152,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 40,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 5020,
#                             "healthRegen": 52,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 175,
#                             "movementSpeed": 446,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 1051,
#                             "powerMax": 1249,
#                             "powerRegen": 62,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1183,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 52877,
#                             "physicalDamageDone": 373555,
#                             "physicalDamageDoneToChampions": 15891,
#                             "physicalDamageTaken": 27631,
#                             "totalDamageDone": 490054,
#                             "totalDamageDoneToChampions": 23093,
#                             "totalDamageTaken": 87869,
#                             "trueDamageDone": 116500,
#                             "trueDamageDoneToChampions": 7202,
#                             "trueDamageTaken": 7359
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 253,
#                         "level": 18,
#                         "minionsKilled": 119,
#                         "participantId": 7,
#                         "position": {
#                             "x": 9984,
#                             "y": 4424
#                         },
#                         "timeEnemySpentControlled": 670185,
#                         "totalGold": 21086,
#                         "xp": 26468
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 110,
#                             "armorPen": 0,
#                             "armorPenPercent": 39,
#                             "attackDamage": 486,
#                             "attackSpeed": 205,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 44,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 2593,
#                             "healthRegen": 31,
#                             "lifesteal": 5,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 138,
#                             "movementSpeed": 380,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 810,
#                             "powerMax": 1024,
#                             "powerRegen": 38,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 2711,
#                         "damageStats": {
#                             "magicDamageDone": 4440,
#                             "magicDamageDoneToChampions": 332,
#                             "magicDamageTaken": 24694,
#                             "physicalDamageDone": 333880,
#                             "physicalDamageDoneToChampions": 31227,
#                             "physicalDamageTaken": 14478,
#                             "totalDamageDone": 346797,
#                             "totalDamageDoneToChampions": 32071,
#                             "totalDamageTaken": 41749,
#                             "trueDamageDone": 8476,
#                             "trueDamageDoneToChampions": 511,
#                             "trueDamageTaken": 2575
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 32,
#                         "level": 18,
#                         "minionsKilled": 282,
#                         "participantId": 8,
#                         "position": {
#                             "x": 11436,
#                             "y": 4665
#                         },
#                         "timeEnemySpentControlled": 100313,
#                         "totalGold": 22309,
#                         "xp": 25250
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 104,
#                             "armorPen": 0,
#                             "armorPenPercent": 30,
#                             "attackDamage": 515,
#                             "attackSpeed": 151,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 2796,
#                             "healthRegen": 29,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 54,
#                             "movementSpeed": 433,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 838,
#                             "powerMax": 1230,
#                             "powerRegen": 43,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1954,
#                         "damageStats": {
#                             "magicDamageDone": 4051,
#                             "magicDamageDoneToChampions": 1506,
#                             "magicDamageTaken": 30062,
#                             "physicalDamageDone": 297768,
#                             "physicalDamageDoneToChampions": 41552,
#                             "physicalDamageTaken": 15750,
#                             "totalDamageDone": 309197,
#                             "totalDamageDoneToChampions": 44976,
#                             "totalDamageTaken": 47776,
#                             "trueDamageDone": 7377,
#                             "trueDamageDoneToChampions": 1916,
#                             "trueDamageTaken": 1963
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 8,
#                         "level": 18,
#                         "minionsKilled": 252,
#                         "participantId": 9,
#                         "position": {
#                             "x": 11462,
#                             "y": 7706
#                         },
#                         "timeEnemySpentControlled": 193896,
#                         "totalGold": 21478,
#                         "xp": 21591
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 434,
#                             "armor": 106,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 114,
#                             "attackSpeed": 127,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 2889,
#                             "healthRegen": 51,
#                             "lifesteal": 0,
#                             "magicPen": 18,
#                             "magicPenPercent": 8,
#                             "magicResist": 96,
#                             "movementSpeed": 427,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 1152,
#                             "powerMax": 1426,
#                             "powerRegen": 105,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1519,
#                         "damageStats": {
#                             "magicDamageDone": 75402,
#                             "magicDamageDoneToChampions": 39617,
#                             "magicDamageTaken": 26890,
#                             "physicalDamageDone": 4012,
#                             "physicalDamageDoneToChampions": 535,
#                             "physicalDamageTaken": 12799,
#                             "totalDamageDone": 97016,
#                             "totalDamageDoneToChampions": 49532,
#                             "totalDamageTaken": 44711,
#                             "trueDamageDone": 17601,
#                             "trueDamageDoneToChampions": 9379,
#                             "trueDamageTaken": 5020
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 6,
#                         "level": 18,
#                         "minionsKilled": 41,
#                         "participantId": 10,
#                         "position": {
#                             "x": 11573,
#                             "y": 11127
#                         },
#                         "timeEnemySpentControlled": 248923,
#                         "totalGold": 16413,
#                         "xp": 18962
#                     }
#                 },
#                 "timestamp": 3021567
#             }
#         ],
#         "gameId": 5219664701,
#         "participants": [
#             {
#                 "participantId": 1,
#                 "puuid": "psIS-jEiD395_Ze7jGUezx-STXKsfgtGEYJxztdc5ii-bA7UQ9k70GMW2anf5dtnwryGziSVJszuxQ"
#             },
#             {
#                 "participantId": 2,
#                 "puuid": "lrsd6NxJUGdsY8wQ4pkl208cwMWtxdPDc9nmxkMjnYe8PdblQLnaKm4p7uzhPxWD_1rllXwnZ-SIbA"
#             },
#             {
#                 "participantId": 3,
#                 "puuid": "D9Eq35nDgsihaTtECccCww59bkNWnBddmF0LBfV4dm1i-miFecX3tNK4AI6LtB-moBuKntPQuhj9kA"
#             },
#             {
#                 "participantId": 4,
#                 "puuid": "WZmqhqzBa35voA3eSKANMmjMP5zt4GFyZz0DLCvt5Omou6Z4vkbyjTV5YEdTJusmAZtuy1GWmwA12A"
#             },
#             {
#                 "participantId": 5,
#                 "puuid": "hbLouJSQ9Tw_qliI6LjADHit0zC32mGdJWmFPvsuSIrCnfG9rbzx1P_nvnQ5vVTTTppHJ4Tk9jrnWQ"
#             },
#             {
#                 "participantId": 6,
#                 "puuid": "9MaIkv3NSX8k9sHxIUNWTGOZZQhp5PqkfOYuGnY8vWf_1-LpOiLDTKjNvoDbW8dwgDpcP-V_Sh0oHw"
#             },
#             {
#                 "participantId": 7,
#                 "puuid": "-TOZutRRUM-3xDPWgKtXkGWxKht2klcGLhMPy4y42Dvwtjunp_DW-T-P_hi8wO-BSNBBaAcE_lrU1w"
#             },
#             {
#                 "participantId": 8,
#                 "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA"
#             },
#             {
#                 "participantId": 9,
#                 "puuid": "t39gBaAwIVbvXfZw7QZh_XeeeqPWXsVEfheJdvhbye7AcrDTRzhOjM53ABt-85MQjQVQS7-DTogHxA"
#             },
#             {
#                 "participantId": 10,
#                 "puuid": "KUghYHlmqKjqv-DEixUt7mj8tx0PuDGVZ16C3fQXR2YkHeZyMlV3_Z1YSxOaClzm_-dB4iwOJ-paWA"
#             }
#         ]
#     }
# }

# %%
import json
with open("test.json", "r") as file:
    event = json.load(file)
import grab as gb

gb.blue_gold_from_kill(event, True)
# Out:
# 1406.0

# %%
import pandas as pd

# Dynamic feature column names
dynamic_columns = [
    "damageTypeRatio", "goldDifference", "averageAllyLvl", "averageEnemyLvl", "averageAllyToFountain", 
    "averageEnemytoFountain", "alliedDragons", "enemyDragons", "alliedGrubs", "enemyGrubs", "topTurrets", 
    "enemytopTurrets", "midTurrets", "enemyMidTurrets", "botTurrets", "enemyBotTurrets", "inhibsTaken", 
    "enemyInhibsTaken", "tillAlliedNT1", "tillAlliedNT2", "tillEnemyNT1", "tillEnemyNT2", "featsOfStrength", 
    "atakhan", "hasSoul", "tookHerald", "untilBaronExp", "untilElderExp", "untilGrubsSpawn", "untilHeraldSpawn", 
    "untilBaronSpawn", "untilDragonSpawn", "untilElderSpawn", "avgAlliedRespawn", "avgEnemyRespawn", 
    "secondsElapsed"
]

# Static feature column names
static_columns = [
    "CCScore", "enemyCCScore", "isSquishy", "vsSquishy", 'objective', "matchId", "team", "Patch"
]

# Combine column names in the required order
column_names = dynamic_columns + static_columns + ["rank", "region"]

# Create empty DataFrame
df = pd.DataFrame(columns=column_names)

# Display DataFrame structure
display(df.head())
df.to_parquet('objective_data.parquet')
# Out:
# Empty DataFrame
# Columns: [damageTypeRatio, goldDifference, averageAllyLvl, averageEnemyLvl, averageAllyToFountain, averageEnemytoFountain, alliedDragons, enemyDragons, alliedGrubs, enemyGrubs, topTurrets, enemytopTurrets, midTurrets, enemyMidTurrets, botTurrets, enemyBotTurrets, inhibsTaken, enemyInhibsTaken, tillAlliedNT1, tillAlliedNT2, tillEnemyNT1, tillEnemyNT2, featsOfStrength, atakhan, hasSoul, tookHerald, untilBaronExp, untilElderExp, untilGrubsSpawn, untilHeraldSpawn, untilBaronSpawn, untilDragonSpawn, untilElderSpawn, avgAlliedRespawn, avgEnemyRespawn, secondsElapsed, CCScore, enemyCCScore, isSquishy, vsSquishy, objective, matchId, team, Patch, rank, region]
# Index: []
#
# [0 rows x 46 columns]
