# %%
import requests
import json
import os
from dotenv import load_dotenv
from pulsefire.clients import RiotAPIClient

load_dotenv()

API_KEY = os.getenv('RIOTAPI')
MISTRAL_KEY = os.getenv('MISTRAL_KEY')
REGION = "na1"

# %%
async with RiotAPIClient(default_headers={"X-Riot-Token": API_KEY}) as client: 
    account = await client.get_account_v1_by_riot_id(region='americas',
                                                    game_name='LukePhysicist',
                                                    tag_line='NA1')
    matches = await client.get_lol_match_v5_match_ids_by_puuid(region='americas',
                                                               puuid=account['puuid'],
                                                               queries = {'start':0, 'count':15})
    league_match = await client.get_lol_match_v5_match(region='americas',
                                                 id=matches[2])
    match_timeline = await client.get_lol_match_v5_match_timeline(region='americas', id=matches[0])
print(json.dumps(account,indent=4))
print(json.dumps(matches,indent=4))
# Out:
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 async with RiotAPIClient(default_headers={"X-Riot-Token": API_KEY}) as client:
# ----> 2     account = await client.get_account_v1_by_riot_id(region='americas',
#       3                                                     game_name='LukePhysicist',
#       4                                                     tag_line='NA1')
#       5     matches = await client.get_lol_match_v5_match_ids_by_puuid(region='americas',
#       6                                                                puuid=account['puuid'],
#       7                                                                queries = {'start':0, 'count':15})
#       8     league_match = await client.get_lol_match_v5_match(region='americas',
#       9                                                  id=matches[2])
#
# File c:\Users\Luke\Desktop\SELF_LEARNING\LoL_Objective_Strength\.venv\Lib\site-packages\pulsefire\clients.py:384, in RiotAPIClient.get_account_v1_by_riot_id(self, region, game_name, tag_line)
#     383 async def get_account_v1_by_riot_id(self, *, region: Region = ..., game_name: str = ..., tag_line: str = ...) -> RiotAPISchema.AccountV1Account:
# --> 384     return await self.invoke("GET", "/riot/account/v1/accounts/by-riot-id/{game_name}/{tag_line}")
#
# File c:\Users\Luke\Desktop\SELF_LEARNING\LoL_Objective_Strength\.venv\Lib\site-packages\pulsefire\clients.py:147, in BaseClient.invoke(self, method, path_or_url)
#     145 invoker: MethodType | None = getattr(self, sys._getframe(1).f_code.co_name, None)
#     146 invocation = Invocation(method, self.base_url + path_or_url, params, self.session, invoker=invoker)
# --> 147 return await self.middleware_begin(invocation)
#
# File c:\Users\Luke\Desktop\SELF_LEARNING\LoL_Objective_Strength\.venv\Lib\site-packages\pulsefire\middlewares.py:105, in json_response_middleware.<locals>.constructor.<locals>.middleware(invocation)
#     104 async def middleware(invocation: Invocation):
# --> 105     response: aiohttp.ClientResponse = await next(invocation)
#     106     try:
#     107         return await response.json(encoding="utf-8", content_type=None, loads=loads)
#
# File c:\Users\Luke\Desktop\SELF_LEARNING\LoL_Objective_Strength\.venv\Lib\site-packages\pulsefire\middlewares.py:74, in http_error_middleware.<locals>.constructor.<locals>.middleware(invocation)
#      72         return response
#      73     if not (response.status == 429 or response.status >= 500):
# ---> 74         response.raise_for_status()
#      75 else:
#      76     if last_response:
#
# File c:\Users\Luke\Desktop\SELF_LEARNING\LoL_Objective_Strength\.venv\Lib\site-packages\aiohttp\client_reqrep.py:1121, in ClientResponse.raise_for_status(self)
#    1118 if not self._in_context:
#    1119     self.release()
# -> 1121 raise ClientResponseError(
#    1122     self.request_info,
#    1123     self.history,
#    1124     status=self.status,
#    1125     message=self.reason,
#    1126     headers=self.headers,
#    1127 )
#
# ClientResponseError: 403, message='Forbidden', url='https://americas.api.riotgames.com/riot/account/v1/accounts/by-riot-id/LukePhysicist/NA1'

# %%
print(json.dumps(league_match,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5215170472",
#         "participants": [
#             "KGRD5vDEaU0MOhoL-12HJhlL-cm0dUL3AdOiKNjilVYtswswMthStPasGnYZIVZd9mBs9k_pNgpzQA",
#             "Ka2pRGpiqTFixFVexKDcfgKpctLEe8b5qN2RBlXjPhUQyVU-v2qsh_aYrcdcwORrm8-fhyVJprc1Zg",
#             "A3-prme3sv3iBGQwdy_RBQATguWsL35LEJ_pYXfXKOhqKRxSB6urllrymuGshLl52dXAzUaVFNodrA",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "psO-IkN7gwkptk11_pe41jIgcvvsDJWFEc4H0AA-gcJ-t2ZgDMBHIqJVjQVtuD-lZbaeYsGUndfOng",
#             "8WD9fdPngenfhANWjtY4S5QRjS0RmAfZzmjd453Shm3vtxxUWUTAJ74wdWJDb-jwBQREFv7uU0Q2Zw",
#             "TDFsNpGl5VQRp8B4Nmzm5RvHD1SGpf0pYCeXhp4DYvze6xMGj7v4SGdiQWQb7z6W26eB53Lcs_E0uA",
#             "BAbFZX1uLQGYBLuFLGk6zd0GEPDNU_Ct7VmybdkXz4FhRqfnAzW-isrcJVM-DnUoaBKWlSUwhzWqVA",
#             "yo7gSp1PY48NgrtXIuhDyPNPHgEV399tetza6UZSeAgmZHSs8uTRCr2FnE_BpnMqckQ1QxpceVl9mQ",
#             "DiAVj0PIW9TX9rEutlMZUQvy6mnHIKMx9-VY4qGlxnvRCIy0G-FJe7PLHB6s3UOhbldTqmfxP2lRNw"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "gameCreation": 1737860479123,
#         "gameDuration": 1593,
#         "gameEndTimestamp": 1737862104435,
#         "gameId": 5215170472,
#         "gameMode": "CLASSIC",
#         "gameName": "teambuilder-match-5215170472",
#         "gameStartTimestamp": 1737860511040,
#         "gameType": "MATCHED_GAME",
#         "gameVersion": "15.2.652.1536",
#         "mapId": 11,
#         "participants": [
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 1,
#                 "assists": 4,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 3,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 6,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 211,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 881.1217626485301,
#                     "damageTakenOnTeamPercentage": 0.2970724011258559,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 5,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 63,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 1,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1593.8324625290002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 357.3867289719202,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 2,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 1.4,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.4666666666666667,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 2,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 2,
#                     "landSkillShotsEarlyGame": 8,
#                     "laneMinionsFirst10Minutes": 81,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3068,
#                         3084,
#                         3075
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 25,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 2,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 1,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 5,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 23,
#                     "skillshotsHit": 51,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 2,
#                     "soloTurretsLategame": 1,
#                     "stealthWardsPlaced": 8,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 2,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 7,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 3,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.2862827225818793,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 1,
#                     "turretPlatesTaken": 3,
#                     "turretTakedowns": 1,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.02805352210998535,
#                     "visionScorePerMinute": 0.5146878326145093,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 0,
#                     "wardTakedownsBefore20M": 0,
#                     "wardsGuarded": 1
#                 },
#                 "champExperience": 12743,
#                 "champLevel": 14,
#                 "championId": 516,
#                 "championName": "Ornn",
#                 "championTransform": 0,
#                 "commandPings": 7,
#                 "consumablesPurchased": 0,
#                 "damageDealtToBuildings": 3244,
#                 "damageDealtToObjectives": 3244,
#                 "damageDealtToTurrets": 3244,
#                 "damageSelfMitigated": 41044,
#                 "dangerPings": 0,
#                 "deaths": 5,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 1,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 16,
#                 "enemyVisionPings": 1,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 17,
#                 "goldEarned": 9493,
#                 "goldSpent": 9050,
#                 "holdPings": 0,
#                 "individualPosition": "TOP",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 1,
#                 "item0": 1054,
#                 "item1": 2031,
#                 "item2": 3068,
#                 "item3": 3084,
#                 "item4": 3075,
#                 "item5": 1029,
#                 "item6": 3340,
#                 "itemsPurchased": 17,
#                 "killingSprees": 1,
#                 "kills": 3,
#                 "lane": "TOP",
#                 "largestCriticalStrike": 23,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 2,
#                 "longestTimeSpentLiving": 445,
#                 "magicDamageDealt": 60922,
#                 "magicDamageDealtToChampions": 15370,
#                 "magicDamageTaken": 14474,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 16,
#                 "participantId": 1,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5001,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8437,
#                                     "var1": 1117,
#                                     "var2": 913,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8446,
#                                     "var1": 2356,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8473,
#                                     "var1": 1249,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8451,
#                                     "var1": 268,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8009,
#                                     "var1": 1469,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9105,
#                                     "var1": 16,
#                                     "var2": 30,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 46683,
#                 "physicalDamageDealtToChampions": 8035,
#                 "physicalDamageTaken": 22188,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6499,
#                 "pushPings": 0,
#                 "puuid": "KGRD5vDEaU0MOhoL-12HJhlL-cm0dUL3AdOiKNjilVYtswswMthStPasGnYZIVZd9mBs9k_pNgpzQA",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "Jax  Main",
#                 "riotIdTagline": "42KID",
#                 "role": "DUO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 74,
#                 "spell2Casts": 74,
#                 "spell3Casts": 47,
#                 "spell4Casts": 16,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 4,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 4,
#                 "summoner2Id": 12,
#                 "summonerId": "Ts6_W5ZVrUl0iLeuG6UCodOaiSJlAVIS7UdCjhcP0SCfhgugNTSrkcezSg",
#                 "summonerLevel": 87,
#                 "summonerName": "BobPotatoIV",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "TOP",
#                 "timeCCingOthers": 40,
#                 "timePlayed": 1593,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 107605,
#                 "totalDamageDealtToChampions": 23406,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 37291,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 5262,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 176,
#                 "totalTimeCCDealt": 452,
#                 "totalTimeSpentDead": 161,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 0,
#                 "trueDamageDealtToChampions": 0,
#                 "trueDamageTaken": 628,
#                 "turretKills": 1,
#                 "turretTakedowns": 1,
#                 "turretsLost": 7,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 13,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 0,
#                 "wardsPlaced": 8,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 1,
#                 "assists": 6,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 5,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 272.91250228881836,
#                     "InfernalScalePickup": 15,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 292,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 243.75997924804688,
#                     "buffsStolen": 7,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 1,
#                     "damagePerMinute": 590.0610871814816,
#                     "damageTakenOnTeamPercentage": 0.30232779585225705,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 4,
#                     "dodgeSkillShotsSmallWindow": 3,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 1,
#                     "earliestDragonTakedown": 513.796857527,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 21,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1593.8324625290002,
#                     "goldPerMinute": 357.33228325959465,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 3,
#                     "initialBuffCount": 2,
#                     "initialCrabCount": 1,
#                     "jungleCsBefore10Minutes": 64.00000008940697,
#                     "junglerKillsEarlyJungle": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 2.75,
#                     "killAfterHiddenWithAlly": 1,
#                     "killParticipation": 0.7333333333333333,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 1,
#                     "killsNearEnemyTurret": 1,
#                     "killsOnLanersEarlyJungleAsJungler": 1,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 2,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 0,
#                     "laneMinionsFirst10Minutes": 1,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3084,
#                         3053
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 5,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 10,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 3,
#                     "skillshotsDodged": 65,
#                     "skillshotsHit": 1,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "stealthWardsPlaced": 2,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 11,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 6,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.19171504063204062,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 0,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.14362716674804688,
#                     "visionScorePerMinute": 0.7545739227470815,
#                     "voidMonsterKill": 1,
#                     "wardTakedowns": 5,
#                     "wardTakedownsBefore20M": 5,
#                     "wardsGuarded": 1
#                 },
#                 "champExperience": 12334,
#                 "champLevel": 14,
#                 "championId": 72,
#                 "championName": "Skarner",
#                 "championTransform": 0,
#                 "commandPings": 1,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 79,
#                 "damageDealtToObjectives": 16005,
#                 "damageDealtToTurrets": 79,
#                 "damageSelfMitigated": 49293,
#                 "dangerPings": 0,
#                 "deaths": 4,
#                 "detectorWardsPlaced": 1,
#                 "doubleKills": 0,
#                 "dragonKills": 1,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 6,
#                 "enemyVisionPings": 2,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 2,
#                 "goldEarned": 9492,
#                 "goldSpent": 9175,
#                 "holdPings": 0,
#                 "individualPosition": "JUNGLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 1,
#                 "item0": 3053,
#                 "item1": 3084,
#                 "item2": 3047,
#                 "item3": 1011,
#                 "item4": 1029,
#                 "item5": 1029,
#                 "item6": 3364,
#                 "itemsPurchased": 18,
#                 "killingSprees": 1,
#                 "kills": 5,
#                 "lane": "JUNGLE",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 3,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 680,
#                 "magicDamageDealt": 30224,
#                 "magicDamageDealtToChampions": 4683,
#                 "magicDamageTaken": 7689,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 138,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 4,
#                 "participantId": 2,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5011,
#                         "flex": 5001,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8437,
#                                     "var1": 941,
#                                     "var2": 646,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8401,
#                                     "var1": 1325,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8429,
#                                     "var1": 54,
#                                     "var2": 12,
#                                     "var3": 10
#                                 },
#                                 {
#                                     "perk": 8451,
#                                     "var1": 242,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8304,
#                                     "var1": 10,
#                                     "var2": 3,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8410,
#                                     "var1": 87,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8300
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 80724,
#                 "physicalDamageDealtToChampions": 10583,
#                 "physicalDamageTaken": 29981,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 29,
#                 "pushPings": 0,
#                 "puuid": "Ka2pRGpiqTFixFVexKDcfgKpctLEe8b5qN2RBlXjPhUQyVU-v2qsh_aYrcdcwORrm8-fhyVJprc1Zg",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "\u80d6\u80d6\u8822\u8822\u6076\u5fc3\u5fc3",
#                 "riotIdTagline": "7449",
#                 "role": "NONE",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 136,
#                 "spell2Casts": 98,
#                 "spell3Casts": 51,
#                 "spell4Casts": 7,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 12,
#                 "summoner1Id": 11,
#                 "summoner2Casts": 2,
#                 "summoner2Id": 4,
#                 "summonerId": "xL7F2U1c1KtwtPC8sFXg5bDW_mS7VhVEh0I4nEbzZhkAdtpoj8wfTXi2OQ",
#                 "summonerLevel": 54,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "JUNGLE",
#                 "timeCCingOthers": 33,
#                 "timePlayed": 1593,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 176196,
#                 "totalDamageDealtToChampions": 15674,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 37951,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 16188,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 17,
#                 "totalTimeCCDealt": 586,
#                 "totalTimeSpentDead": 138,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 65246,
#                 "trueDamageDealtToChampions": 408,
#                 "trueDamageTaken": 280,
#                 "turretKills": 0,
#                 "turretTakedowns": 0,
#                 "turretsLost": 7,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 20,
#                 "visionWardsBoughtInGame": 1,
#                 "wardsKilled": 5,
#                 "wardsPlaced": 3,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 1,
#                 "assistMePings": 7,
#                 "assists": 3,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 5,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 68,
#                     "InfernalScalePickup": 5,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 340,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 616.5368347167969,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 807.4268257126081,
#                     "damageTakenOnTeamPercentage": 0.1616401773114199,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 5,
#                     "dodgeSkillShotsSmallWindow": 2,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 1,
#                     "earliestDragonTakedown": 863.054621256,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 8,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 1,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1593.8324625290002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 397.8151518629037,
#                     "hadOpenNexus": 0,
#                     "highestCrowdControlScore": 1,
#                     "immobilizeAndKillWithAlly": 3,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 1,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 1.6,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.5333333333333333,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 1,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 0,
#                     "laneMinionsFirst10Minutes": 74,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3118,
#                         2503,
#                         6653,
#                         3116
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 21,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 7,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 63,
#                     "skillshotsHit": 0,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "soloTurretsLategame": 1,
#                     "stealthWardsPlaced": 8,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 8,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 4,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.2623387138411359,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 2,
#                     "turretTakedowns": 1,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.11130952835083008,
#                     "visionScorePerMinute": 0.6035254709409746,
#                     "voidMonsterKill": 1,
#                     "wardTakedowns": 2,
#                     "wardTakedownsBefore20M": 0,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 13141,
#                 "champLevel": 15,
#                 "championId": 90,
#                 "championName": "Malzahar",
#                 "championTransform": 0,
#                 "commandPings": 5,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 4025,
#                 "damageDealtToObjectives": 13391,
#                 "damageDealtToTurrets": 4025,
#                 "damageSelfMitigated": 11437,
#                 "dangerPings": 0,
#                 "deaths": 5,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 1,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 18,
#                 "enemyVisionPings": 1,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 12,
#                 "goldEarned": 10567,
#                 "goldSpent": 10200,
#                 "holdPings": 0,
#                 "individualPosition": "MIDDLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 1,
#                 "item0": 6653,
#                 "item1": 2503,
#                 "item2": 3116,
#                 "item3": 1056,
#                 "item4": 3020,
#                 "item5": 0,
#                 "item6": 3340,
#                 "itemsPurchased": 20,
#                 "killingSprees": 1,
#                 "kills": 5,
#                 "lane": "TOP",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 761,
#                 "magicDamageDealt": 120076,
#                 "magicDamageDealtToChampions": 21127,
#                 "magicDamageTaken": 3728,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 1,
#                 "neutralMinionsKilled": 8,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 11,
#                 "participantId": 3,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8229,
#                                     "var1": 1457,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8226,
#                                     "var1": 250,
#                                     "var2": 923,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8210,
#                                     "var1": 1,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8237,
#                                     "var1": 564,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8304,
#                                     "var1": 11,
#                                     "var2": 1,
#                                     "var3": 5
#                                 },
#                                 {
#                                     "perk": 8347,
#                                     "var1": 0,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8300
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 8639,
#                 "physicalDamageDealtToChampions": 321,
#                 "physicalDamageTaken": 15182,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 29,
#                 "pushPings": 0,
#                 "puuid": "A3-prme3sv3iBGQwdy_RBQATguWsL35LEJ_pYXfXKOhqKRxSB6urllrymuGshLl52dXAzUaVFNodrA",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "YON",
#                 "riotIdTagline": "11731",
#                 "role": "DUO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 116,
#                 "spell2Casts": 119,
#                 "spell3Casts": 97,
#                 "spell4Casts": 8,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 5,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 4,
#                 "summoner2Id": 12,
#                 "summonerId": "PLDW6XNuqDgkCoVmB7Nw3JY80C--h25dy1KUHutJNofJmb7J3GwQsvcGNA",
#                 "summonerLevel": 49,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "MIDDLE",
#                 "timeCCingOthers": 55,
#                 "timePlayed": 1593,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 133221,
#                 "totalDamageDealtToChampions": 21448,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 20290,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 2131,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 187,
#                 "totalTimeCCDealt": 382,
#                 "totalTimeSpentDead": 191,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 4505,
#                 "trueDamageDealtToChampions": 0,
#                 "trueDamageTaken": 1380,
#                 "turretKills": 1,
#                 "turretTakedowns": 1,
#                 "turretsLost": 7,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 16,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 2,
#                 "wardsPlaced": 8,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 2,
#                 "assists": 5,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 1,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 3,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 111,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 137.75,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 545.1001046928995,
#                     "damageTakenOnTeamPercentage": 0.11175932884297919,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 3,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 1,
#                     "earliestDragonTakedown": 863.054621256,
# ...
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "fasterSupportQuestCompletion": 1,
#                     "firstTurretKilled": 1,
#                     "firstTurretKilledTime": 871.219077263,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1593.8324625290002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 255.0394142501372,
#                     "hadOpenNexus": 0,
#                     "highestWardKills": 1,
#                     "immobilizeAndKillWithAlly": 1,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 2,
#                     "killAfterHiddenWithAlly": 3,
#                     "killParticipation": 0.3,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 1,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 1,
#                     "laneMinionsFirst10Minutes": 14,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3870,
#                         6620
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 19,
#                     "maxKillDeficit": 1,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 1,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 5,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 24,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 67,
#                     "skillshotsHit": 14,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "stealthWardsPlaced": 21,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 4,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 6,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 3,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.06749659083372224,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 1,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 4,
#                     "turretsTakenWithRiftHerald": 5,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 1,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.2773715853691101,
#                     "visionScorePerMinute": 2.0198989347071885,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 6,
#                     "wardTakedownsBefore20M": 2,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 9469,
#                 "champLevel": 12,
#                 "championId": 40,
#                 "championName": "Janna",
#                 "championTransform": 0,
#                 "commandPings": 9,
#                 "consumablesPurchased": 4,
#                 "damageDealtToBuildings": 3893,
#                 "damageDealtToObjectives": 4229,
#                 "damageDealtToTurrets": 3893,
#                 "damageSelfMitigated": 7070,
#                 "dangerPings": 0,
#                 "deaths": 3,
#                 "detectorWardsPlaced": 2,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 2,
#                 "enemyVisionPings": 4,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 0,
#                 "goldEarned": 6774,
#                 "goldSpent": 5300,
#                 "holdPings": 0,
#                 "individualPosition": "UTILITY",
#                 "inhibitorKills": 1,
#                 "inhibitorTakedowns": 1,
#                 "inhibitorsLost": 0,
#                 "item0": 3870,
#                 "item1": 1028,
#                 "item2": 0,
#                 "item3": 3009,
#                 "item4": 6620,
#                 "item5": 4642,
#                 "item6": 3364,
#                 "itemsPurchased": 15,
#                 "killingSprees": 0,
#                 "kills": 1,
#                 "lane": "BOTTOM",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 0,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 565,
#                 "magicDamageDealt": 13799,
#                 "magicDamageDealtToChampions": 5717,
#                 "magicDamageTaken": 5181,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 0,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 1,
#                 "participantId": 10,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5010,
#                         "offense": 5008
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8214,
#                                     "var1": 848,
#                                     "var2": 731,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8226,
#                                     "var1": 250,
#                                     "var2": 225,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8234,
#                                     "var1": 12616,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8236,
#                                     "var1": 24,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8463,
#                                     "var1": 800,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8453,
#                                     "var1": 852,
#                                     "var2": 535,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 5105,
#                 "physicalDamageDealtToChampions": 876,
#                 "physicalDamageTaken": 7712,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 3231,
#                 "pushPings": 0,
#                 "puuid": "DiAVj0PIW9TX9rEutlMZUQvy6mnHIKMx9-VY4qGlxnvRCIy0G-FJe7PLHB6s3UOhbldTqmfxP2lRNw",
#                 "quadraKills": 0,
#                 "retreatPings": 2,
#                 "riotIdGameName": "Cyra",
#                 "riotIdTagline": "627",
#                 "role": "SUPPORT",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 42,
#                 "spell2Casts": 42,
#                 "spell3Casts": 33,
#                 "spell4Casts": 3,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 3,
#                 "summoner1Id": 7,
#                 "summoner2Casts": 3,
#                 "summoner2Id": 4,
#                 "summonerId": "JMQQisS0Dsdo_jETCUcevDJaZzCD-5Dx-Rh1qGxcpL82BEs",
#                 "summonerLevel": 384,
#                 "summonerName": "Teia",
#                 "teamEarlySurrendered": false,
#                 "teamId": 200,
#                 "teamPosition": "UTILITY",
#                 "timeCCingOthers": 26,
#                 "timePlayed": 1593,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 28600,
#                 "totalDamageDealtToChampions": 6660,
#                 "totalDamageShieldedOnTeammates": 3600,
#                 "totalDamageTaken": 13067,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 7015,
#                 "totalHealsOnTeammates": 4856,
#                 "totalMinionsKilled": 40,
#                 "totalTimeCCDealt": 157,
#                 "totalTimeSpentDead": 41,
#                 "totalUnitsHealed": 9,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 9695,
#                 "trueDamageDealtToChampions": 66,
#                 "trueDamageTaken": 174,
#                 "turretKills": 1,
#                 "turretTakedowns": 4,
#                 "turretsLost": 2,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 53,
#                 "visionWardsBoughtInGame": 2,
#                 "wardsKilled": 6,
#                 "wardsPlaced": 23,
#                 "win": true
#             }
#         ],
#         "platformId": "NA1",
#         "queueId": 420,
#         "teams": [
#             {
#                 "bans": [
#                     {
#                         "championId": 147,
#                         "pickTurn": 1
#                     },
#                     {
#                         "championId": 143,
#                         "pickTurn": 2
#                     },
#                     {
#                         "championId": -1,
#                         "pickTurn": 3
#                     },
#                     {
#                         "championId": 800,
#                         "pickTurn": 4
#                     },
#                     {
#                         "championId": 86,
#                         "pickTurn": 5
#                     }
#                 ],
#                 "objectives": {
#                     "atakhan": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "baron": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "champion": {
#                         "first": false,
#                         "kills": 15
#                     },
#                     "dragon": {
#                         "first": true,
#                         "kills": 2
#                     },
#                     "horde": {
#                         "first": false,
#                         "kills": 1
#                     },
#                     "inhibitor": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "riftHerald": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "tower": {
#                         "first": false,
#                         "kills": 2
#                     }
#                 },
#                 "teamId": 100,
#                 "win": false
#             },
#             {
#                 "bans": [
#                     {
#                         "championId": 555,
#                         "pickTurn": 6
#                     },
#                     {
#                         "championId": 234,
#                         "pickTurn": 7
#                     },
#                     {
#                         "championId": 119,
#                         "pickTurn": 8
#                     },
#                     {
#                         "championId": 266,
#                         "pickTurn": 9
#                     },
#                     {
#                         "championId": 800,
#                         "pickTurn": 10
#                     }
#                 ],
#                 "objectives": {
#                     "baron": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "champion": {
#                         "first": true,
#                         "kills": 20
#                     },
#                     "dragon": {
#                         "first": false,
#                         "kills": 2
#                     },
#                     "horde": {
#                         "first": true,
#                         "kills": 5
#                     },
#                     "inhibitor": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "riftHerald": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "tower": {
#                         "first": true,
#                         "kills": 7
#                     }
#                 },
#                 "teamId": 200,
#                 "win": true
#             }
#         ],
#         "tournamentCode": ""
#     }
# }

# %%
print(json.dumps(match_timeline,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5215414793",
#         "participants": [
#             "VgznkQf4PoDYf33tk-frIEPoklteOSz_pUmeSSd4sYS8u_GPIS_PDgKV5AAZ_eV2hgFmnDPwaSh57g",
#             "S7IpyJc_dGkg3_w1WEm3bBN9YgfxO4dRNW2xf6HKF4PP9offTQMfegdjtYwFKBFklUxYilapRC8LwQ",
#             "jVUKw7DlKnZR1uShU0IY68sUOD89DiiBdqyX9a7ZRNRRGslzsf15E5xcCeFWkBFKKXSU9kUqpEcazA",
#             "qYH7ybB4YMP9nBuq9pA92aabX0puRs55TKMlBk7Feu6ajZo_suK-yLKzGE325UY5BTci3evKSZupdg",
#             "T5mgAmw3-6tTRL_EKe_-VWU4iXpKWt6MiWJrSitlpnqKPPZPJPMZSAMOS-QAx41jLG4_EyTDhv9TLw",
#             "IX7skvM32NPso-2vG5JOF_LshIX5ORezo6wzNS0CzGYa7sxbiEjgMHh3eChRyB_71mSSMsxSNRkoGw",
#             "9uG-4jsXIDcnJZ2lak7an65sks1ysAL6_aJNGYTYaUSskPLCxoGQAuZrC6Y6-AG_sKNU9k0oqa579A",
#             "ADP5RF_i0cKtSsDAuESQbn2IM3rvft7E7Op74sVbR53hfitFVQhbA8NEN03qClx5CVd2-gAXNoPjjw",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "3RRw4_Yxit0DvNld2zqzrKna-U7XRaE1KfCWJ-i-CxO4OghM_64mnMAUUmwT3srR3qYQRBx5_Pb9RA"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "frameInterval": 60000,
#         "frames": [
#             {
#                 "events": [
#                     {
#                         "realTimestamp": 1737874879573,
#                         "timestamp": 0,
#                         "type": "PAUSE_END"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 23,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 550,
#                             "healthMax": 550,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 232,
#                             "powerMax": 232,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 554,
#                             "y": 581
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 22,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 605,
#                             "healthMax": 605,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 410,
#                             "powerMax": 410,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 593,
#                             "y": 464
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 25,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 563,
#                             "healthMax": 563,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 480,
#                             "powerMax": 480,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 557,
#                             "y": 345
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 28,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 640,
#                             "healthMax": 640,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 325,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 300,
#                             "powerMax": 300,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 458,
#                             "y": 271
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 28,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 630,
#                             "healthMax": 630,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 374,
#                             "powerMax": 374,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 5,
#                         "position": {
#                             "x": 335,
#                             "y": 269
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 35,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 665,
#                             "healthMax": 665,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 375,
#                             "powerMax": 375,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 6,
#                         "position": {
#                             "x": 14500,
#                             "y": 14511
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 610,
#                             "healthMax": 610,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 280,
#                             "powerMax": 280,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 7,
#                         "position": {
#                             "x": 14539,
#                             "y": 14394
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 32,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 590,
#                             "healthMax": 590,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 125,
#                             "powerMax": 125,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 8,
#                         "position": {
#                             "x": 14503,
#                             "y": 14275
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 675,
#                             "healthMax": 675,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 361,
#                             "powerMax": 361,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 9,
#                         "position": {
#                             "x": 14404,
#                             "y": 14201
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 560,
#                             "healthMax": 560,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 365,
#                             "powerMax": 365,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 10,
#                         "position": {
#                             "x": 14281,
#                             "y": 14199
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     }
#                 },
#                 "timestamp": 0
#             },
#             {
#                 "events": [
#                     {
#                         "itemId": 1054,
#                         "participantId": 8,
#                         "timestamp": 2100,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 8,
#                         "timestamp": 2100,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 8,
#                         "timestamp": 2601,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 4,
#                         "timestamp": 3937,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 4,
#                         "timestamp": 3937,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 4,
#                         "timestamp": 4371,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 9,
#                         "timestamp": 6876,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 9,
#                         "timestamp": 6876,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 9,
#                         "timestamp": 7244,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1102,
#                         "participantId": 2,
#                         "timestamp": 8413,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 9,
#                         "skillSlot": 1,
#                         "timestamp": 8480,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1054,
#                         "participantId": 6,
#                         "timestamp": 11453,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 6,
#                         "timestamp": 11453,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 6,
#                         "timestamp": 12355,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 5,
#                         "timestamp": 13023,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 13023,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 13023,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 10,
#                         "timestamp": 13056,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 5,
#                         "timestamp": 13323,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 13457,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 13591,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 2,
#                         "skillSlot": 1,
#                         "timestamp": 16663,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 1,
#                         "timestamp": 18868,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 1,
#                         "timestamp": 19101,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 1,
#                         "timestamp": 19369,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1056,
#                         "participantId": 3,
#                         "timestamp": 19669,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 19669,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 19669,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 1,
#                         "skillSlot": 1,
#                         "timestamp": 23276,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1103,
#                         "participantId": 7,
#                         "timestamp": 24445,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 7,
#                         "timestamp": 25247,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 7,
#                         "timestamp": 25581,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 5,
#                         "skillSlot": 1,
#                         "timestamp": 30457,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 4,
#                         "skillSlot": 1,
#                         "timestamp": 34666,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 10,
#                         "skillSlot": 2,
#                         "timestamp": 36403,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 3,
#                         "skillSlot": 1,
#                         "timestamp": 39342,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 7,
#                         "skillSlot": 2,
#                         "timestamp": 41379,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 6,
#                         "skillSlot": 2,
#                         "timestamp": 43483,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 8,
#                         "skillSlot": 3,
#                         "timestamp": 45688,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 6,
#                         "timestamp": 48894,
#                         "type": "ITEM_DESTROYED"
#                     },
#                     {
#                         "creatorId": 7,
#                         "timestamp": 55106,
#                         "type": "WARD_PLACED",
#                         "wardType": "YELLOW_TRINKET"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 7,
#                         "timestamp": 57177,
#                         "type": "ITEM_DESTROYED"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 23,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 75,
#                             "attackSpeed": 141,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 170,
#                             "healthMax": 695,
#                             "healthRegen": 7,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 165,
#                             "powerMax": 232,
#                             "powerRegen": 14,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 723,
#                             "physicalDamageDoneToChampions": 723,
#                             "physicalDamageTaken": 540,
#                             "totalDamageDone": 723,
#                             "totalDamageDoneToChampions": 723,
#                             "totalDamageTaken": 540,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 10595,
#                             "y": 4656
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 18,
#                             "armor": 22,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 61,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 576,
#                             "healthMax": 615,
#                             "healthRegen": 5,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 323,
#                             "powerMax": 410,
#                             "powerRegen": 46,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 50,
#                         "damageStats": {
#                             "magicDamageDone": 134,
#                             "magicDamageDoneToChampions": 134,
#                             "magicDamageTaken": 53,
#                             "physicalDamageDone": 93,
#                             "physicalDamageDoneToChampions": 93,
#                             "physicalDamageTaken": 15,
#                             "totalDamageDone": 315,
#                             "totalDamageDoneToChampions": 315,
#                             "totalDamageTaken": 68,
#                             "trueDamageDone": 87,
#                             "trueDamageDoneToChampions": 87,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 10787,
#                             "y": 3324
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 27,
#                             "armor": 25,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 54,
#                             "attackSpeed": 110,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 285,
#                             "healthMax": 663,
#                             "healthRegen": 13,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 442,
#                             "powerMax": 505,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 99,
#                             "magicDamageDoneToChampions": 99,
#                             "magicDamageTaken": 199,
#                             "physicalDamageDone": 71,
#                             "physicalDamageDoneToChampions": 71,
#                             "physicalDamageTaken": 193,
#                             "totalDamageDone": 171,
#                             "totalDamageDoneToChampions": 171,
#                             "totalDamageTaken": 392,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 11010,
#                             "y": 1986
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 28,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 68,
#                             "attackSpeed": 110,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 574,
#                             "healthMax": 785,
#                             "healthRegen": 7,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 325,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 214,
#                             "powerMax": 350,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 106,
#                             "physicalDamageDone": 986,
#                             "physicalDamageDoneToChampions": 986,
#                             "physicalDamageTaken": 233,
#                             "totalDamageDone": 986,
#                             "totalDamageDoneToChampions": 986,
#                             "totalDamageTaken": 339,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 11884,
#                             "y": 3156
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 18,
#                             "armor": 28,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 51,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 277,
#                             "healthMax": 725,
#                             "healthRegen": 13,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
# ...
#                             "magicDamageTaken": 1650,
#                             "physicalDamageDone": 4207,
#                             "physicalDamageDoneToChampions": 962,
#                             "physicalDamageTaken": 5762,
#                             "totalDamageDone": 20617,
#                             "totalDamageDoneToChampions": 6843,
#                             "totalDamageTaken": 7413,
#                             "trueDamageDone": 2906,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 4,
#                         "level": 11,
#                         "minionsKilled": 24,
#                         "participantId": 5,
#                         "position": {
#                             "x": 13241,
#                             "y": 12072
#                         },
#                         "timeEnemySpentControlled": 150791,
#                         "totalGold": 6095,
#                         "xp": 7616
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 25,
#                             "armor": 186,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 96,
#                             "attackSpeed": 125,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 836,
#                             "healthMax": 2468,
#                             "healthRegen": 24,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 77,
#                             "movementSpeed": 360,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 1500,
#                             "powerMax": 1798,
#                             "powerRegen": 23,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 326,
#                         "damageStats": {
#                             "magicDamageDone": 47537,
#                             "magicDamageDoneToChampions": 6518,
#                             "magicDamageTaken": 6742,
#                             "physicalDamageDone": 11589,
#                             "physicalDamageDoneToChampions": 1037,
#                             "physicalDamageTaken": 12324,
#                             "totalDamageDone": 59127,
#                             "totalDamageDoneToChampions": 7556,
#                             "totalDamageTaken": 22637,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 3570
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 12,
#                         "minionsKilled": 140,
#                         "participantId": 6,
#                         "position": {
#                             "x": 13356,
#                             "y": 10571
#                         },
#                         "timeEnemySpentControlled": 278602,
#                         "totalGold": 6651,
#                         "xp": 9852
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 104,
#                             "armor": 129,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 93,
#                             "attackSpeed": 129,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 29,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 2025,
#                             "healthRegen": 27,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 74,
#                             "movementSpeed": 397,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 600,
#                             "powerMax": 739,
#                             "powerRegen": 24,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1756,
#                         "damageStats": {
#                             "magicDamageDone": 44243,
#                             "magicDamageDoneToChampions": 7277,
#                             "magicDamageTaken": 9043,
#                             "physicalDamageDone": 17677,
#                             "physicalDamageDoneToChampions": 693,
#                             "physicalDamageTaken": 16779,
#                             "totalDamageDone": 166107,
#                             "totalDamageDoneToChampions": 8097,
#                             "totalDamageTaken": 27118,
#                             "trueDamageDone": 104185,
#                             "trueDamageDoneToChampions": 125,
#                             "trueDamageTaken": 1295
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 128,
#                         "level": 13,
#                         "minionsKilled": 16,
#                         "participantId": 7,
#                         "position": {
#                             "x": 13510,
#                             "y": 12396
#                         },
#                         "timeEnemySpentControlled": 308653,
#                         "totalGold": 7941,
#                         "xp": 10178
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 82,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 162,
#                             "attackSpeed": 221,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 2211,
#                             "healthRegen": 40,
#                             "lifesteal": 10,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 54,
#                             "movementSpeed": 390,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 181,
#                             "powerMax": 430,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1315,
#                         "damageStats": {
#                             "magicDamageDone": 13510,
#                             "magicDamageDoneToChampions": 1596,
#                             "magicDamageTaken": 5686,
#                             "physicalDamageDone": 82264,
#                             "physicalDamageDoneToChampions": 11413,
#                             "physicalDamageTaken": 8779,
#                             "totalDamageDone": 95775,
#                             "totalDamageDoneToChampions": 13009,
#                             "totalDamageTaken": 15436,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 970
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 13,
#                         "minionsKilled": 192,
#                         "participantId": 8,
#                         "position": {
#                             "x": 13676,
#                             "y": 12261
#                         },
#                         "timeEnemySpentControlled": 90285,
#                         "totalGold": 7640,
#                         "xp": 11180
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 73,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 281,
#                             "attackSpeed": 166,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 1843,
#                             "healthRegen": 21,
#                             "lifesteal": 21,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 42,
#                             "movementSpeed": 375,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 165,
#                             "powerMax": 744,
#                             "powerRegen": 28,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1198,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 5295,
#                             "physicalDamageDone": 92009,
#                             "physicalDamageDoneToChampions": 11891,
#                             "physicalDamageTaken": 13563,
#                             "totalDamageDone": 92029,
#                             "totalDamageDoneToChampions": 11911,
#                             "totalDamageTaken": 20026,
#                             "trueDamageDone": 19,
#                             "trueDamageDoneToChampions": 19,
#                             "trueDamageTaken": 1166
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 12,
#                         "minionsKilled": 163,
#                         "participantId": 9,
#                         "position": {
#                             "x": 14030,
#                             "y": 12644
#                         },
#                         "timeEnemySpentControlled": 60691,
#                         "totalGold": 8383,
#                         "xp": 8700
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 74,
#                             "armor": 69,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 77,
#                             "attackSpeed": 125,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 1741,
#                             "healthRegen": 34,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 40,
#                             "movementSpeed": 394,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 187,
#                             "powerMax": 697,
#                             "powerRegen": 87,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1232,
#                         "damageStats": {
#                             "magicDamageDone": 7043,
#                             "magicDamageDoneToChampions": 4649,
#                             "magicDamageTaken": 3413,
#                             "physicalDamageDone": 4657,
#                             "physicalDamageDoneToChampions": 1235,
#                             "physicalDamageTaken": 9477,
#                             "totalDamageDone": 13751,
#                             "totalDamageDoneToChampions": 5885,
#                             "totalDamageTaken": 13389,
#                             "trueDamageDone": 2050,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 499
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 0,
#                         "level": 10,
#                         "minionsKilled": 23,
#                         "participantId": 10,
#                         "position": {
#                             "x": 13005,
#                             "y": 11663
#                         },
#                         "timeEnemySpentControlled": 100285,
#                         "totalGold": 5087,
#                         "xp": 7092
#                     }
#                 },
#                 "timestamp": 1347348
#             }
#         ],
#         "gameId": 5215414793,
#         "participants": [
#             {
#                 "participantId": 1,
#                 "puuid": "VgznkQf4PoDYf33tk-frIEPoklteOSz_pUmeSSd4sYS8u_GPIS_PDgKV5AAZ_eV2hgFmnDPwaSh57g"
#             },
#             {
#                 "participantId": 2,
#                 "puuid": "S7IpyJc_dGkg3_w1WEm3bBN9YgfxO4dRNW2xf6HKF4PP9offTQMfegdjtYwFKBFklUxYilapRC8LwQ"
#             },
#             {
#                 "participantId": 3,
#                 "puuid": "jVUKw7DlKnZR1uShU0IY68sUOD89DiiBdqyX9a7ZRNRRGslzsf15E5xcCeFWkBFKKXSU9kUqpEcazA"
#             },
#             {
#                 "participantId": 4,
#                 "puuid": "qYH7ybB4YMP9nBuq9pA92aabX0puRs55TKMlBk7Feu6ajZo_suK-yLKzGE325UY5BTci3evKSZupdg"
#             },
#             {
#                 "participantId": 5,
#                 "puuid": "T5mgAmw3-6tTRL_EKe_-VWU4iXpKWt6MiWJrSitlpnqKPPZPJPMZSAMOS-QAx41jLG4_EyTDhv9TLw"
#             },
#             {
#                 "participantId": 6,
#                 "puuid": "IX7skvM32NPso-2vG5JOF_LshIX5ORezo6wzNS0CzGYa7sxbiEjgMHh3eChRyB_71mSSMsxSNRkoGw"
#             },
#             {
#                 "participantId": 7,
#                 "puuid": "9uG-4jsXIDcnJZ2lak7an65sks1ysAL6_aJNGYTYaUSskPLCxoGQAuZrC6Y6-AG_sKNU9k0oqa579A"
#             },
#             {
#                 "participantId": 8,
#                 "puuid": "ADP5RF_i0cKtSsDAuESQbn2IM3rvft7E7Op74sVbR53hfitFVQhbA8NEN03qClx5CVd2-gAXNoPjjw"
#             },
#             {
#                 "participantId": 9,
#                 "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA"
#             },
#             {
#                 "participantId": 10,
#                 "puuid": "3RRw4_Yxit0DvNld2zqzrKna-U7XRaE1KfCWJ-i-CxO4OghM_64mnMAUUmwT3srR3qYQRBx5_Pb9RA"
#             }
#         ]
#     }
# }

# %%
import grab as gb
import json
with open("test.json", 'r', encoding='utf-8') as file:
    snapshot = json.load(file)

gb.damage_type_ratio(snapshot=snapshot, team=100)
# Out:
# 1.7680421270718232
