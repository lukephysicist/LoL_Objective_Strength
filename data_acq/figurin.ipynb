# %%
import requests
import json
import os
from dotenv import load_dotenv
from pulsefire.clients import RiotAPIClient

load_dotenv()

API_KEY = os.getenv('RIOTAPI')
MISTRAL_KEY = os.getenv('MISTRAL_KEY')
REGION = "na1"

# %%
async with RiotAPIClient(default_headers={"X-Riot-Token": API_KEY}) as client: 
    account = await client.get_account_v1_by_riot_id(region='americas',
                                                    game_name='LukePhysicist',
                                                    tag_line='NA1')
    matches = await client.get_lol_match_v5_match_ids_by_puuid(region='americas',
                                                               puuid=account['puuid'],
                                                               queries = {'start':0, 'count':15})
    league_match = await client.get_lol_match_v5_match(region='americas',
                                                 id=matches[2])
    match_timeline = await client.get_lol_match_v5_match_timeline(region='americas', id=matches[0])
print(json.dumps(account,indent=4))
print(json.dumps(matches,indent=4))
# Out:
# {
#     "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#     "gameName": "LukePhysicist",
#     "tagLine": "NA1"
# }
# [
#     "NA1_5213903565",
#     "NA1_5213310561",
#     "NA1_5213283955",
#     "NA1_5212530255",
#     "NA1_5211787117",
#     "NA1_5211144004",
#     "NA1_5211112934",
#     "NA1_5211091080",
#     "NA1_5211016608",
#     "NA1_5211001960",
#     "NA1_5210993424",
#     "NA1_5210991946",
#     "NA1_5210979453",
#     "NA1_5210306619",
#     "NA1_5210292243"
# ]

# %%
print(json.dumps(league_match,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5213283955",
#         "participants": [
#             "nmgD7gEos9h-604eM_THdK78WYkSyYioE2jlL0a0GF7CXO9vypnPe9r61-24SpchuEkBrsH4oelOJw",
#             "l9wsF48Y9HkJfqCHMf2MEifhFgXNA0vNCKZP8hjXA6MKSdmH2W9xvjqwySvYFSJbR7wEV45FKOYibg",
#             "46mWY8MVGpReJZt8NvhM2bdg0Yx9Mbx9iJTQkgO-w1Xby6EvfG2fU30soJfoX193MhEBLdGcmHOUyw",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "7_ZoIN9t2W8geEWB9wak3hRJQJWdx_n3lIwXBVS69ZYkwGQEoMR13QYlhkTt7ho7jnC98SaAdK2sVg",
#             "5jqe0D_gN832obhlhf88rxw6wEJtJpNvNqH_qF1RkbRMcHtGzMlmer-lkE7TdH7mBRGybw5JWwJuug",
#             "1iBqdqLedwMjQGzo0jzBvVL4pugyQwucy7xeF5hlaYHts2Y5ydKb3iOs-lDkgNl8OVXF3PnNPYq6-Q",
#             "BTVWCBSbie8TwQ4CSGUGnQI2X-VTD4hAn4uWzqm9pWK5JeiAIBfo_vdXu9KP5DVe_N4Kk00II-Tf5g",
#             "FJEF0KCcDAYEpAtLCPwkXFqOqUJLfhjE-Ym60BWY8Iyi5c0Cf8xo5uQ_pC6w_QF3MBi2uHlTxpHTpQ",
#             "DDuC6EGrgYYuMvZtfq-5K4xyExii1XfjQw0VR9Wjl2J5HX-f9SiOC3NDYPesfLtI6kmAqACWTz2N_A"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "gameCreation": 1737677588135,
#         "gameDuration": 1676,
#         "gameEndTimestamp": 1737679295291,
#         "gameId": 5213283955,
#         "gameMode": "CLASSIC",
#         "gameName": "teambuilder-match-5213283955",
#         "gameStartTimestamp": 1737677618655,
#         "gameType": "MATCHED_GAME",
#         "gameVersion": "15.2.652.1536",
#         "mapId": 11,
#         "participants": [
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 3,
#                 "assists": 5,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 3,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 27,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 317,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 179.114990234375,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 1117.6415071737854,
#                     "damageTakenOnTeamPercentage": 0.2642591604417881,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 7,
#                     "dodgeSkillShotsSmallWindow": 4,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 0,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1677.2829943390002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 325.9950636880944,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 0,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 1.1428571428571428,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.42105263157894735,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 2,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 16,
#                     "laneMinionsFirst10Minutes": 39,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3084,
#                         2502
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 0,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 5,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 47,
#                     "skillshotsHit": 64,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 2,
#                     "soloTurretsLategame": 1,
#                     "stealthWardsPlaced": 10,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 8,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 3,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.3669366981737769,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 2,
#                     "turretPlatesTaken": 2,
#                     "turretTakedowns": 1,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.24351346492767334,
#                     "visionScorePerMinute": 0.43982076850398705,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 0,
#                     "wardTakedownsBefore20M": 0,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 14503,
#                 "champLevel": 15,
#                 "championId": 36,
#                 "championName": "DrMundo",
#                 "championTransform": 0,
#                 "commandPings": 2,
#                 "consumablesPurchased": 1,
#                 "damageDealtToBuildings": 3877,
#                 "damageDealtToObjectives": 3877,
#                 "damageDealtToTurrets": 3877,
#                 "damageSelfMitigated": 39447,
#                 "dangerPings": 0,
#                 "deaths": 7,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 3,
#                 "enemyVisionPings": 0,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 0,
#                 "goldEarned": 9113,
#                 "goldSpent": 9100,
#                 "holdPings": 0,
#                 "individualPosition": "TOP",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 3,
#                 "item0": 3084,
#                 "item1": 2502,
#                 "item2": 3211,
#                 "item3": 1028,
#                 "item4": 2022,
#                 "item5": 3047,
#                 "item6": 3340,
#                 "itemsPurchased": 21,
#                 "killingSprees": 1,
#                 "kills": 3,
#                 "lane": "TOP",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 476,
#                 "magicDamageDealt": 48297,
#                 "magicDamageDealtToChampions": 20185,
#                 "magicDamageTaken": 14945,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 1,
#                 "participantId": 1,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5001,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8437,
#                                     "var1": 1891,
#                                     "var2": 1186,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8446,
#                                     "var1": 1603,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8444,
#                                     "var1": 3042,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8451,
#                                     "var1": 267,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8304,
#                                     "var1": 9,
#                                     "var2": 4,
#                                     "var3": 5
#                                 },
#                                 {
#                                     "perk": 8410,
#                                     "var1": 111,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8300
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 84895,
#                 "physicalDamageDealtToChampions": 10824,
#                 "physicalDamageTaken": 37072,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 4414,
#                 "pushPings": 0,
#                 "puuid": "nmgD7gEos9h-604eM_THdK78WYkSyYioE2jlL0a0GF7CXO9vypnPe9r61-24SpchuEkBrsH4oelOJw",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "f0cheur",
#                 "riotIdTagline": "NA1",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 165,
#                 "spell2Casts": 67,
#                 "spell3Casts": 76,
#                 "spell4Casts": 9,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 4,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 1,
#                 "summoner2Id": 12,
#                 "summonerId": "6SalhnAAZZx2w9KXjI38cfVl2K57vkpIrsMaqH5JAC9HU_tTg3xC7brghg",
#                 "summonerLevel": 479,
#                 "summonerName": "f0cheur",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "TOP",
#                 "timeCCingOthers": 24,
#                 "timePlayed": 1676,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 134486,
#                 "totalDamageDealtToChampions": 31243,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 53233,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 17263,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 148,
#                 "totalTimeCCDealt": 277,
#                 "totalTimeSpentDead": 182,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 1294,
#                 "trueDamageDealtToChampions": 234,
#                 "trueDamageTaken": 1215,
#                 "turretKills": 1,
#                 "turretTakedowns": 1,
#                 "turretsLost": 11,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 12,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 0,
#                 "wardsPlaced": 10,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 7,
#                 "assists": 5,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 7,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 14,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 234,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 1210.974365234375,
#                     "buffsStolen": 7,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 657.6797838591491,
#                     "damageTakenOnTeamPercentage": 0.26311316505227733,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 9,
#                     "dodgeSkillShotsSmallWindow": 5,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 1,
#                     "earliestDragonTakedown": 757.9097365800001,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 31,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1677.2829943390002,
#                     "goldPerMinute": 394.79208285657097,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 6,
#                     "initialBuffCount": 2,
#                     "initialCrabCount": 1,
#                     "jungleCsBefore10Minutes": 62.00000011920929,
#                     "junglerKillsEarlyJungle": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 1.3333333333333333,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.631578947368421,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnLanersEarlyJungleAsJungler": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 1,
#                     "killsWithHelpFromEpicMonster": 1,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 0,
#                     "laneMinionsFirst10Minutes": 1,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3748,
#                         3084,
#                         3071
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 12.000000059604645,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 9,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 1,
#                     "skillshotsDodged": 69,
#                     "skillshotsHit": 10,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 2,
#                     "stealthWardsPlaced": 3,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 12,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 5,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.21592509476063576,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 0,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.5559324026107788,
#                     "visionScorePerMinute": 0.5951726999976459,
#                     "voidMonsterKill": 3,
#                     "wardTakedowns": 4,
#                     "wardTakedownsBefore20M": 3,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 11911,
#                 "champLevel": 14,
#                 "championId": 233,
#                 "championName": "Briar",
#                 "championTransform": 0,
#                 "commandPings": 1,
#                 "consumablesPurchased": 0,
#                 "damageDealtToBuildings": 0,
#                 "damageDealtToObjectives": 12908,
#                 "damageDealtToTurrets": 0,
#                 "damageSelfMitigated": 28224,
#                 "dangerPings": 0,
#                 "deaths": 9,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 6,
#                 "enemyVisionPings": 3,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 2,
#                 "goldEarned": 11036,
#                 "goldSpent": 10800,
#                 "holdPings": 0,
#                 "individualPosition": "JUNGLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 3,
#                 "item0": 3084,
#                 "item1": 3748,
#                 "item2": 3071,
#                 "item3": 3009,
#                 "item4": 1036,
#                 "item5": 0,
#                 "item6": 3364,
#                 "itemsPurchased": 19,
#                 "killingSprees": 2,
#                 "kills": 7,
#                 "lane": "JUNGLE",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 371,
#                 "magicDamageDealt": 14861,
#                 "magicDamageDealtToChampions": 3681,
#                 "magicDamageTaken": 12449,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 117,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 6,
#                 "participantId": 2,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5011,
#                         "flex": 5008,
#                         "offense": 5008
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8010,
#                                     "var1": 242,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9111,
#                                     "var1": 1117,
#                                     "var2": 240,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9104,
#                                     "var1": 11,
#                                     "var2": 40,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8014,
#                                     "var1": 740,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8304,
#                                     "var1": 9,
#                                     "var2": 4,
#                                     "var3": 5
#                                 },
#                                 {
#                                     "perk": 8347,
#                                     "var1": 0,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8300
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 115718,
#                 "physicalDamageDealtToChampions": 14202,
#                 "physicalDamageTaken": 37504,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 4606,
#                 "pushPings": 0,
#                 "puuid": "l9wsF48Y9HkJfqCHMf2MEifhFgXNA0vNCKZP8hjXA6MKSdmH2W9xvjqwySvYFSJbR7wEV45FKOYibg",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "crooklookbill",
#                 "riotIdTagline": "NA1",
#                 "role": "NONE",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 57,
#                 "spell2Casts": 137,
#                 "spell3Casts": 33,
#                 "spell4Casts": 7,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 16,
#                 "summoner1Id": 11,
#                 "summoner2Casts": 3,
#                 "summoner2Id": 4,
#                 "summonerId": "b5Hx3pKoWL7-gs638B5EKJyHZjDxGAMHa4S_5GthIkLbkhQ",
#                 "summonerLevel": 566,
#                 "summonerName": "crooklookbill",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "JUNGLE",
#                 "timeCCingOthers": 28,
#                 "timePlayed": 1676,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 175090,
#                 "totalDamageDealtToChampions": 18385,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 53002,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 35287,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 27,
#                 "totalTimeCCDealt": 177,
#                 "totalTimeSpentDead": 248,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 44511,
#                 "trueDamageDealtToChampions": 502,
#                 "trueDamageTaken": 3048,
#                 "turretKills": 0,
#                 "turretTakedowns": 0,
#                 "turretsLost": 11,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 16,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 4,
#                 "wardsPlaced": 3,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 0,
#                 "assists": 6,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 4,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 91.77168273925781,
#                     "InfernalScalePickup": 21,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 193,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 280.6556396484375,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 561.0492460432138,
#                     "damageTakenOnTeamPercentage": 0.2198347022020965,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 5,
#                     "dodgeSkillShotsSmallWindow": 9,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 1,
#                     "earliestDragonTakedown": 757.9097365800001,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 20,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1677.2829943390002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 392.02243200043694,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 3,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 2,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.5263157894736842,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 1,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 2,
#                     "laneMinionsFirst10Minutes": 84,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         6664,
#                         2502,
#                         3075
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 60,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 7,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 84,
#                     "skillshotsHit": 13,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 1,
#                     "stealthWardsPlaced": 7,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 10,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 4,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.18419999305195142,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 0,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.2384982705116272,
#                     "visionScorePerMinute": 0.4077470336464387,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 0,
#                     "wardTakedownsBefore20M": 0,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 15532,
#                 "champLevel": 16,
#                 "championId": 14,
#                 "championName": "Sion",
#                 "championTransform": 0,
#                 "commandPings": 2,
#                 "consumablesPurchased": 1,
#                 "damageDealtToBuildings": 1350,
#                 "damageDealtToObjectives": 2762,
#                 "damageDealtToTurrets": 1350,
#                 "damageSelfMitigated": 48367,
#                 "dangerPings": 0,
#                 "deaths": 5,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 2,
#                 "enemyVisionPings": 3,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 4,
#                 "goldEarned": 10958,
#                 "goldSpent": 10930,
#                 "holdPings": 0,
#                 "individualPosition": "MIDDLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 3,
#                 "item0": 3009,
#                 "item1": 6664,
#                 "item2": 3077,
#                 "item3": 3075,
#                 "item4": 2502,
#                 "item5": 0,
#                 "item6": 3340,
#                 "itemsPurchased": 19,
#                 "killingSprees": 1,
#                 "kills": 4,
#                 "lane": "MIDDLE",
#                 "largestCriticalStrike": 7,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 1053,
#                 "magicDamageDealt": 61812,
#                 "magicDamageDealtToChampions": 7396,
#                 "magicDamageTaken": 11276,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 3,
#                 "participantId": 3,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8437,
#                                     "var1": 1328,
#                                     "var2": 755,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8446,
#                                     "var1": 939,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8444,
#                                     "var1": 1736,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8451,
#                                     "var1": 272,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 9105,
#                                     "var1": 15,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9111,
#                                     "var1": 1111,
#                                     "var2": 200,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 84191,
#                 "physicalDamageDealtToChampions": 8046,
#                 "physicalDamageTaken": 28081,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 5508,
#                 "pushPings": 0,
#                 "puuid": "46mWY8MVGpReJZt8NvhM2bdg0Yx9Mbx9iJTQkgO-w1Xby6EvfG2fU30soJfoX193MhEBLdGcmHOUyw",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "AWeebaboo",
#                 "riotIdTagline": "6969",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 71,
#                 "spell2Casts": 70,
#                 "spell3Casts": 45,
#                 "spell4Casts": 7,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 2,
#                 "summoner1Id": 12,
#                 "summoner2Casts": 3,
#                 "summoner2Id": 4,
#                 "summonerId": "MBXFY3tM7EPNMetNBQXDSW8FNUfLqqgcy7zTKDLkQu16SJI",
#                 "summonerLevel": 570,
#                 "summonerName": "OmegaMemeyBoi",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "MIDDLE",
#                 "timeCCingOthers": 24,
#                 "timePlayed": 1676,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 148340,
#                 "totalDamageDealtToChampions": 15683,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 44284,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 6024,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 223,
#                 "totalTimeCCDealt": 620,
#                 "totalTimeSpentDead": 171,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 2336,
#                 "trueDamageDealtToChampions": 240,
#                 "trueDamageTaken": 4927,
#                 "turretKills": 0,
#                 "turretTakedowns": 0,
#                 "turretsLost": 11,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 11,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 0,
#                 "wardsPlaced": 7,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 0,
#                 "assists": 6,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 1,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 74,
#                     "InfernalScalePickup": 7,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 154,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 539.902587890625,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 319.0217323901106,
#                     "damageTakenOnTeamPercentage": 0.0893658156841159,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 9,
#                     "dodgeSkillShotsSmallWindow": 6,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 1,
#                     "earliestDragonTakedown": 757.9097365800001,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
# ...
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 1,
#                     "firstTurretKilledTime": 829.6578301940001,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1677.2829943390002,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 310.52088884693796,
#                     "hadOpenNexus": 0,
#                     "highestWardKills": 1,
#                     "immobilizeAndKillWithAlly": 8,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 14,
#                     "killAfterHiddenWithAlly": 4,
#                     "killParticipation": 0.3684210526315789,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 7,
#                     "laneMinionsFirst10Minutes": 12,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3871,
#                         6655,
#                         3135
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 1,
#                     "maxKillDeficit": 1,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 12,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 5,
#                     "skillshotsHit": 26,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "stealthWardsPlaced": 32,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 14,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 4,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 1,
#                     "teamDamagePercentage": 0.08938491685610087,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 1,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 1,
#                     "turretTakedowns": 5,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 1,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.002375006675720215,
#                     "visionScorePerMinute": 2.795476707161153,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 10,
#                     "wardTakedownsBefore20M": 4,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 10503,
#                 "champLevel": 13,
#                 "championId": 7,
#                 "championName": "Leblanc",
#                 "championTransform": 0,
#                 "commandPings": 11,
#                 "consumablesPurchased": 4,
#                 "damageDealtToBuildings": 4580,
#                 "damageDealtToObjectives": 8677,
#                 "damageDealtToTurrets": 4580,
#                 "damageSelfMitigated": 4187,
#                 "dangerPings": 0,
#                 "deaths": 1,
#                 "detectorWardsPlaced": 2,
#                 "doubleKills": 0,
#                 "dragonKills": 1,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 10,
#                 "enemyVisionPings": 1,
#                 "firstBloodAssist": true,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": false,
#                 "getBackPings": 0,
#                 "goldEarned": 8680,
#                 "goldSpent": 8150,
#                 "holdPings": 0,
#                 "individualPosition": "UTILITY",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 0,
#                 "item0": 3871,
#                 "item1": 6655,
#                 "item2": 3020,
#                 "item3": 3135,
#                 "item4": 0,
#                 "item5": 0,
#                 "item6": 3364,
#                 "itemsPurchased": 21,
#                 "killingSprees": 0,
#                 "kills": 1,
#                 "lane": "BOTTOM",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 0,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 1496,
#                 "magicDamageDealt": 22508,
#                 "magicDamageDealtToChampions": 13541,
#                 "magicDamageTaken": 3660,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 8,
#                 "nexusKills": 0,
#                 "nexusLost": 0,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 23,
#                 "participantId": 10,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5011,
#                         "flex": 5008,
#                         "offense": 5008
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8112,
#                                     "var1": 723,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8143,
#                                     "var1": 831,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8137,
#                                     "var1": 4,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8135,
#                                     "var1": 450,
#                                     "var2": 5,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8100
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8237,
#                                     "var1": 383,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8233,
#                                     "var1": 21,
#                                     "var2": 10,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 4676,
#                 "physicalDamageDealtToChampions": 746,
#                 "physicalDamageTaken": 6407,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6793,
#                 "pushPings": 0,
#                 "puuid": "DDuC6EGrgYYuMvZtfq-5K4xyExii1XfjQw0VR9Wjl2J5HX-f9SiOC3NDYPesfLtI6kmAqACWTz2N_A",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "Pacinian",
#                 "riotIdTagline": "123",
#                 "role": "SUPPORT",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 39,
#                 "spell2Casts": 56,
#                 "spell3Casts": 35,
#                 "spell4Casts": 14,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 5,
#                 "summoner1Id": 14,
#                 "summoner2Casts": 4,
#                 "summoner2Id": 4,
#                 "summonerId": "Dn36huUcSil_SYd5MWXxo3z6jcNiZwDqHxJt_z60rJuWTrfPfUBdFQxAgQ",
#                 "summonerLevel": 368,
#                 "summonerName": "Pacinia",
#                 "teamEarlySurrendered": false,
#                 "teamId": 200,
#                 "teamPosition": "UTILITY",
#                 "timeCCingOthers": 30,
#                 "timePlayed": 1676,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 30853,
#                 "totalDamageDealtToChampions": 15615,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 10298,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 1807,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 25,
#                 "totalTimeCCDealt": 51,
#                 "totalTimeSpentDead": 40,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 3668,
#                 "trueDamageDealtToChampions": 1327,
#                 "trueDamageTaken": 230,
#                 "turretKills": 1,
#                 "turretTakedowns": 5,
#                 "turretsLost": 1,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 78,
#                 "visionWardsBoughtInGame": 2,
#                 "wardsKilled": 10,
#                 "wardsPlaced": 35,
#                 "win": true
#             }
#         ],
#         "platformId": "NA1",
#         "queueId": 420,
#         "teams": [
#             {
#                 "bans": [
#                     {
#                         "championId": 777,
#                         "pickTurn": 1
#                     },
#                     {
#                         "championId": 143,
#                         "pickTurn": 2
#                     },
#                     {
#                         "championId": 56,
#                         "pickTurn": 3
#                     },
#                     {
#                         "championId": 893,
#                         "pickTurn": 4
#                     },
#                     {
#                         "championId": 234,
#                         "pickTurn": 5
#                     }
#                 ],
#                 "objectives": {
#                     "baron": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "champion": {
#                         "first": false,
#                         "kills": 20
#                     },
#                     "dragon": {
#                         "first": false,
#                         "kills": 1
#                     },
#                     "horde": {
#                         "first": true,
#                         "kills": 3
#                     },
#                     "inhibitor": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "riftHerald": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "tower": {
#                         "first": false,
#                         "kills": 1
#                     }
#                 },
#                 "teamId": 100,
#                 "win": false
#             },
#             {
#                 "bans": [
#                     {
#                         "championId": -1,
#                         "pickTurn": 6
#                     },
#                     {
#                         "championId": 800,
#                         "pickTurn": 7
#                     },
#                     {
#                         "championId": 54,
#                         "pickTurn": 8
#                     },
#                     {
#                         "championId": 21,
#                         "pickTurn": 9
#                     },
#                     {
#                         "championId": 142,
#                         "pickTurn": 10
#                     }
#                 ],
#                 "objectives": {
#                     "atakhan": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "baron": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "champion": {
#                         "first": true,
#                         "kills": 38
#                     },
#                     "dragon": {
#                         "first": true,
#                         "kills": 3
#                     },
#                     "horde": {
#                         "first": false,
#                         "kills": 3
#                     },
#                     "inhibitor": {
#                         "first": true,
#                         "kills": 3
#                     },
#                     "riftHerald": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "tower": {
#                         "first": true,
#                         "kills": 11
#                     }
#                 },
#                 "teamId": 200,
#                 "win": true
#             }
#         ],
#         "tournamentCode": ""
#     }
# }

# %%
print(json.dumps(match_timeline,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5213903565",
#         "participants": [
#             "KEWP6aE-zPhLaOnqAPaqDRbf8lx-9phVP80xQn4sJ14oZQrYdEyBQlsOirknZjP0DOWpUiFn6UKD3w",
#             "-1NKAsMcXzUQwQ2Sg-pQMRz5MfveQ6ODkX0D8yEWiZrpSdz_r3mx6EiqDRwJ2Gkd3FQxZeaKL3iicA",
#             "R7R1RptoxsOciom8hbLN-0Wg7jJpxvy3psiNEEljv0yqrZcF6zoLqUuJBY8OVyrFytLPt4Okn09yhg",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "UpyFYvpSiErSe4vivHpdcURcCAJ9zV7vxOv4ppp93SMInxWSeRSI65yhvyDonnUDz7UoNKhDVi6QLA",
#             "FUYxyzb4G4xPRVtDStf5g_7A94PC6mtZlUZh7I0Dp_NGpOAwn5JxtSILd9TM0048pGhvSLTr581Lwg",
#             "N_Lp_1tzWq6Iy-OKbFmu8NfpDORZejU7JTU7p8ksxrhmG_IwM52F7SfGNMn_Ric2XZ7OC2fEwQhr_Q",
#             "_yI4moWgOSqDOgdL4U1KuSQV8wOhc7nKcC8dj53Wrl6O2-NNIlh6KZWrqHy1eu1Gl2nsacOBanPj3Q",
#             "E1pFrK2Ib0zlJsWkXUdV4Hppd_pohRBxA-qsxnQLIT_TityQ0qB5yutUXNO6ia0os9ZG-kOaelu_lQ",
#             "CTfBvF0lHpdfzuhBiSS2et64NhlDTdsiS7UokQ0tKA7qb8U-PZnrdoiKVPsXFhzrgFbojOh6dWFJIw"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "frameInterval": 60000,
#         "frames": [
#             {
#                 "events": [
#                     {
#                         "realTimestamp": 1737744109733,
#                         "timestamp": 0,
#                         "type": "PAUSE_END"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 33,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 696,
#                             "healthMax": 696,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 0,
#                             "powerMax": 100,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 554,
#                             "y": 581
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 31,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 640,
#                             "healthMax": 640,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 375,
#                             "powerMax": 375,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 593,
#                             "y": 464
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 21,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 580,
#                             "healthMax": 580,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 480,
#                             "powerMax": 480,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 557,
#                             "y": 345
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 675,
#                             "healthMax": 675,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 361,
#                             "powerMax": 361,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 458,
#                             "y": 271
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 39,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 640,
#                             "healthMax": 640,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 325,
#                             "powerMax": 325,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 5,
#                         "position": {
#                             "x": 335,
#                             "y": 269
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 38,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 690,
#                             "healthMax": 690,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 0,
#                             "powerMax": 0,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 6,
#                         "position": {
#                             "x": 14500,
#                             "y": 14511
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 30,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 620,
#                             "healthMax": 620,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 324,
#                             "powerMax": 324,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 7,
#                         "position": {
#                             "x": 14539,
#                             "y": 14394
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 28,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 630,
#                             "healthMax": 630,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 374,
#                             "powerMax": 374,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 8,
#                         "position": {
#                             "x": 14503,
#                             "y": 14275
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 24,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 600,
#                             "healthMax": 600,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 325,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 375,
#                             "powerMax": 375,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 9,
#                         "position": {
#                             "x": 14404,
#                             "y": 14201
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 35,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 610,
#                             "healthMax": 610,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 280,
#                             "powerMax": 280,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 10,
#                         "position": {
#                             "x": 14281,
#                             "y": 14199
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     }
#                 },
#                 "timestamp": 0
#             },
#             {
#                 "events": [
#                     {
#                         "itemId": 1055,
#                         "participantId": 9,
#                         "timestamp": 1809,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 9,
#                         "timestamp": 1809,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 9,
#                         "timestamp": 2611,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 8,
#                         "timestamp": 3446,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1056,
#                         "participantId": 8,
#                         "timestamp": 4783,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 8,
#                         "timestamp": 5518,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 8,
#                         "timestamp": 5752,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1101,
#                         "participantId": 7,
#                         "timestamp": 13739,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 5,
#                         "timestamp": 13873,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 13873,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 13873,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 1,
#                         "timestamp": 14073,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 1,
#                         "timestamp": 14073,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 5,
#                         "timestamp": 14307,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 10,
#                         "timestamp": 14641,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 1,
#                         "timestamp": 14641,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 7,
#                         "timestamp": 14842,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 10,
#                         "timestamp": 15410,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 8,
#                         "skillSlot": 1,
#                         "timestamp": 15644,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 10,
#                         "timestamp": 16145,
#                         "type": "ITEM_DESTROYED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 10,
#                         "timestamp": 16145,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 16412,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 16579,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 4,
#                         "timestamp": 18116,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 4,
#                         "timestamp": 18116,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 4,
#                         "timestamp": 18483,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1056,
#                         "participantId": 3,
#                         "timestamp": 18717,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 18717,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 18717,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 4,
#                         "skillSlot": 1,
#                         "timestamp": 19552,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 3,
#                         "timestamp": 20287,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 10,
#                         "skillSlot": 3,
#                         "timestamp": 23194,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 6,
#                         "timestamp": 23261,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 6,
#                         "timestamp": 23863,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 6,
#                         "timestamp": 24065,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 3,
#                         "timestamp": 25268,
#                         "type": "ITEM_DESTROYED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 3,
#                         "timestamp": 25268,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 7,
#                         "skillSlot": 2,
#                         "timestamp": 28542,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 1,
#                         "skillSlot": 1,
#                         "timestamp": 28809,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1103,
#                         "participantId": 2,
#                         "timestamp": 30482,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 5,
#                         "skillSlot": 1,
#                         "timestamp": 36431,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 9,
#                         "skillSlot": 1,
#                         "timestamp": 36965,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "creatorId": 9,
#                         "timestamp": 39204,
#                         "type": "WARD_PLACED",
#                         "wardType": "YELLOW_TRINKET"
#                     },
#                     {
#                         "assistingParticipantIds": [
#                             8,
#                             10
#                         ],
#                         "bounty": 300,
#                         "killStreakLength": 0,
#                         "killerId": 9,
#                         "position": {
#                             "x": 12204,
#                             "y": 1228
#                         },
#                         "shutdownBounty": 0,
#                         "timestamp": 41877,
#                         "type": "CHAMPION_KILL",
#                         "victimDamageDealt": [
#                             {
#                                 "basic": true,
#                                 "magicDamage": 0,
#                                 "name": "TahmKench",
#                                 "participantId": 8,
#                                 "physicalDamage": 43,
#                                 "spellName": "tahmkenchbasicattack",
#                                 "spellSlot": 64,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 6,
#                                 "name": "TahmKench",
#                                 "participantId": 8,
#                                 "physicalDamage": 0,
#                                 "spellName": "tahmkenchpassive",
#                                 "spellSlot": 63,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             }
#                         ],
#                         "victimDamageReceived": [
#                             {
#                                 "basic": false,
#                                 "magicDamage": 15,
#                                 "name": "Poppy",
#                                 "participantId": 10,
#                                 "physicalDamage": 50,
#                                 "spellName": "poppybasicattack",
#                                 "spellSlot": 64,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 0,
#                                 "name": "Poppy",
#                                 "participantId": 10,
#                                 "physicalDamage": 0,
#                                 "spellName": "",
#                                 "spellSlot": -1,
#                                 "trueDamage": 20,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 0,
#                                 "name": "Poppy",
#                                 "participantId": 10,
#                                 "physicalDamage": 79,
#                                 "spellName": "poppye",
#                                 "spellSlot": 2,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 0,
#                                 "name": "Ezreal",
#                                 "participantId": 9,
#                                 "physicalDamage": 28,
#                                 "spellName": "",
#                                 "spellSlot": -1,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 0,
#                                 "name": "Ezreal",
#                                 "participantId": 9,
#                                 "physicalDamage": 183,
#                                 "spellName": "ezrealq",
#                                 "spellSlot": 0,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": true,
#                                 "magicDamage": 0,
#                                 "name": "Ezreal",
#                                 "participantId": 9,
#                                 "physicalDamage": 171,
#                                 "spellName": "ezrealbasicattack",
#                                 "spellSlot": 64,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 0,
#                                 "name": "Karma",
#                                 "participantId": 8,
#                                 "physicalDamage": 0,
#                                 "spellName": "",
#                                 "spellSlot": -1,
#                                 "trueDamage": 10,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 15,
#                                 "name": "Karma",
#                                 "participantId": 8,
#                                 "physicalDamage": 0,
#                                 "spellName": "",
#                                 "spellSlot": 7,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": false,
#                                 "magicDamage": 73,
#                                 "name": "Karma",
#                                 "participantId": 8,
#                                 "physicalDamage": 0,
#                                 "spellName": "karmamantra",
#                                 "spellSlot": 3,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": true,
#                                 "magicDamage": 0,
#                                 "name": "Karma",
#                                 "participantId": 8,
#                                 "physicalDamage": 36,
#                                 "spellName": "karmabasicattack",
#                                 "spellSlot": 64,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             },
#                             {
#                                 "basic": true,
#                                 "magicDamage": 0,
#                                 "name": "Karma",
#                                 "participantId": 8,
#                                 "physicalDamage": 73,
#                                 "spellName": "karmabasicattack2",
#                                 "spellSlot": 65,
#                                 "trueDamage": 0,
#                                 "type": "OTHER"
#                             }
#                         ],
#                         "victimId": 5
#                     },
#                     {
#                         "killType": "KILL_FIRST_BLOOD",
#                         "killerId": 9,
#                         "position": {
#                             "x": 12377,
#                             "y": 1462
#                         },
#                         "timestamp": 41877,
#                         "type": "CHAMPION_SPECIAL_KILL"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 33,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 86,
#                             "attackSpeed": 113,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 841,
#                             "healthMax": 841,
#                             "healthRegen": 17,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 0,
#                             "powerMax": 100,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 1482,
#                             "y": 11446
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 9,
#                             "armor": 31,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 57,
#                             "attackSpeed": 128,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
# ...
#                             "physicalDamageDone": 7727,
#                             "physicalDamageDoneToChampions": 3778,
#                             "physicalDamageTaken": 33290,
#                             "totalDamageDone": 38857,
#                             "totalDamageDoneToChampions": 20947,
#                             "totalDamageTaken": 61663,
#                             "trueDamageDone": 3557,
#                             "trueDamageDoneToChampions": 566,
#                             "trueDamageTaken": 7713
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 4,
#                         "level": 16,
#                         "minionsKilled": 31,
#                         "participantId": 5,
#                         "position": {
#                             "x": 5114,
#                             "y": 3189
#                         },
#                         "timeEnemySpentControlled": 248659,
#                         "totalGold": 10682,
#                         "xp": 15732
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 218,
#                             "armorPen": 0,
#                             "armorPenPercent": 35,
#                             "attackDamage": 377,
#                             "attackSpeed": 259,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 3620,
#                             "healthMax": 3620,
#                             "healthRegen": 764,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 103,
#                             "movementSpeed": 488,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 0,
#                             "powerMax": 0,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 2399,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 10067,
#                             "physicalDamageDone": 356379,
#                             "physicalDamageDoneToChampions": 35374,
#                             "physicalDamageTaken": 36632,
#                             "totalDamageDone": 373302,
#                             "totalDamageDoneToChampions": 47415,
#                             "totalDamageTaken": 48362,
#                             "trueDamageDone": 16923,
#                             "trueDamageDoneToChampions": 12041,
#                             "trueDamageTaken": 1663
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 22,
#                         "level": 18,
#                         "minionsKilled": 352,
#                         "participantId": 6,
#                         "position": {
#                             "x": 11487,
#                             "y": 11917
#                         },
#                         "timeEnemySpentControlled": 231743,
#                         "totalGold": 21228,
#                         "xp": 26797
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 601,
#                             "armor": 106,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 106,
#                             "attackSpeed": 152,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 1554,
#                             "healthMax": 2653,
#                             "healthRegen": 31,
#                             "lifesteal": 0,
#                             "magicPen": 48,
#                             "magicPenPercent": 44,
#                             "magicResist": 52,
#                             "movementSpeed": 419,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 737,
#                             "powerMax": 1174,
#                             "powerRegen": 39,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1469,
#                         "damageStats": {
#                             "magicDamageDone": 266733,
#                             "magicDamageDoneToChampions": 29515,
#                             "magicDamageTaken": 18338,
#                             "physicalDamageDone": 39465,
#                             "physicalDamageDoneToChampions": 1931,
#                             "physicalDamageTaken": 25833,
#                             "totalDamageDone": 415190,
#                             "totalDamageDoneToChampions": 34988,
#                             "totalDamageTaken": 44726,
#                             "trueDamageDone": 108986,
#                             "trueDamageDoneToChampions": 3541,
#                             "trueDamageTaken": 554
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 249,
#                         "level": 18,
#                         "minionsKilled": 36,
#                         "participantId": 7,
#                         "position": {
#                             "x": 1212,
#                             "y": 2070
#                         },
#                         "timeEnemySpentControlled": 218018,
#                         "totalGold": 16588,
#                         "xp": 22025
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 315,
#                             "armor": 113,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 107,
#                             "attackSpeed": 151,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 2599,
#                             "healthMax": 2898,
#                             "healthRegen": 29,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 52,
#                             "movementSpeed": 380,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 484,
#                             "powerMax": 1904,
#                             "powerRegen": 53,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1519,
#                         "damageStats": {
#                             "magicDamageDone": 130355,
#                             "magicDamageDoneToChampions": 18278,
#                             "magicDamageTaken": 17090,
#                             "physicalDamageDone": 14189,
#                             "physicalDamageDoneToChampions": 1044,
#                             "physicalDamageTaken": 12701,
#                             "totalDamageDone": 148430,
#                             "totalDamageDoneToChampions": 21464,
#                             "totalDamageTaken": 31025,
#                             "trueDamageDone": 3885,
#                             "trueDamageDoneToChampions": 2140,
#                             "trueDamageTaken": 1233
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 4,
#                         "level": 18,
#                         "minionsKilled": 202,
#                         "participantId": 8,
#                         "position": {
#                             "x": 2222,
#                             "y": 1478
#                         },
#                         "timeEnemySpentControlled": 298402,
#                         "totalGold": 12464,
#                         "xp": 18706
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 103,
#                             "armorPen": 0,
#                             "armorPenPercent": 30,
#                             "attackDamage": 418,
#                             "attackSpeed": 195,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 0,
#                             "healthMax": 3472,
#                             "healthRegen": 30,
#                             "lifesteal": 20,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 52,
#                             "movementSpeed": 385,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 1642,
#                             "powerMax": 2425,
#                             "powerRegen": 51,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 364,
#                         "damageStats": {
#                             "magicDamageDone": 47306,
#                             "magicDamageDoneToChampions": 18258,
#                             "magicDamageTaken": 19495,
#                             "physicalDamageDone": 241140,
#                             "physicalDamageDoneToChampions": 43085,
#                             "physicalDamageTaken": 16028,
#                             "totalDamageDone": 309009,
#                             "totalDamageDoneToChampions": 63969,
#                             "totalDamageTaken": 36269,
#                             "trueDamageDone": 20562,
#                             "trueDamageDoneToChampions": 2624,
#                             "trueDamageTaken": 745
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 4,
#                         "level": 18,
#                         "minionsKilled": 300,
#                         "participantId": 9,
#                         "position": {
#                             "x": 1112,
#                             "y": 1906
#                         },
#                         "timeEnemySpentControlled": 215879,
#                         "totalGold": 18396,
#                         "xp": 21924
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 239,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 198,
#                             "attackSpeed": 148,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 27,
#                             "cooldownReduction": 0,
#                             "health": 1088,
#                             "healthMax": 3485,
#                             "healthRegen": 107,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 127,
#                             "movementSpeed": 395,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 566,
#                             "powerMax": 859,
#                             "powerRegen": 59,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 2397,
#                         "damageStats": {
#                             "magicDamageDone": 3836,
#                             "magicDamageDoneToChampions": 1894,
#                             "magicDamageTaken": 17648,
#                             "physicalDamageDone": 53682,
#                             "physicalDamageDoneToChampions": 13262,
#                             "physicalDamageTaken": 14921,
#                             "totalDamageDone": 64475,
#                             "totalDamageDoneToChampions": 17051,
#                             "totalDamageTaken": 33906,
#                             "trueDamageDone": 6955,
#                             "trueDamageDoneToChampions": 1894,
#                             "trueDamageTaken": 1336
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 4,
#                         "level": 16,
#                         "minionsKilled": 43,
#                         "participantId": 10,
#                         "position": {
#                             "x": 1031,
#                             "y": 1870
#                         },
#                         "timeEnemySpentControlled": 369550,
#                         "totalGold": 11676,
#                         "xp": 14797
#                     }
#                 },
#                 "timestamp": 2370307
#             }
#         ],
#         "gameId": 5213903565,
#         "participants": [
#             {
#                 "participantId": 1,
#                 "puuid": "KEWP6aE-zPhLaOnqAPaqDRbf8lx-9phVP80xQn4sJ14oZQrYdEyBQlsOirknZjP0DOWpUiFn6UKD3w"
#             },
#             {
#                 "participantId": 2,
#                 "puuid": "-1NKAsMcXzUQwQ2Sg-pQMRz5MfveQ6ODkX0D8yEWiZrpSdz_r3mx6EiqDRwJ2Gkd3FQxZeaKL3iicA"
#             },
#             {
#                 "participantId": 3,
#                 "puuid": "R7R1RptoxsOciom8hbLN-0Wg7jJpxvy3psiNEEljv0yqrZcF6zoLqUuJBY8OVyrFytLPt4Okn09yhg"
#             },
#             {
#                 "participantId": 4,
#                 "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA"
#             },
#             {
#                 "participantId": 5,
#                 "puuid": "UpyFYvpSiErSe4vivHpdcURcCAJ9zV7vxOv4ppp93SMInxWSeRSI65yhvyDonnUDz7UoNKhDVi6QLA"
#             },
#             {
#                 "participantId": 6,
#                 "puuid": "FUYxyzb4G4xPRVtDStf5g_7A94PC6mtZlUZh7I0Dp_NGpOAwn5JxtSILd9TM0048pGhvSLTr581Lwg"
#             },
#             {
#                 "participantId": 7,
#                 "puuid": "N_Lp_1tzWq6Iy-OKbFmu8NfpDORZejU7JTU7p8ksxrhmG_IwM52F7SfGNMn_Ric2XZ7OC2fEwQhr_Q"
#             },
#             {
#                 "participantId": 8,
#                 "puuid": "_yI4moWgOSqDOgdL4U1KuSQV8wOhc7nKcC8dj53Wrl6O2-NNIlh6KZWrqHy1eu1Gl2nsacOBanPj3Q"
#             },
#             {
#                 "participantId": 9,
#                 "puuid": "E1pFrK2Ib0zlJsWkXUdV4Hppd_pohRBxA-qsxnQLIT_TityQ0qB5yutUXNO6ia0os9ZG-kOaelu_lQ"
#             },
#             {
#                 "participantId": 10,
#                 "puuid": "CTfBvF0lHpdfzuhBiSS2et64NhlDTdsiS7UokQ0tKA7qb8U-PZnrdoiKVPsXFhzrgFbojOh6dWFJIw"
#             }
#         ]
#     }
# }

# %%
from grab import *

team_is_squishy(league_match,100)
# Out:
# 0
