# %%
import requests
import json
import os
from dotenv import load_dotenv
from pulsefire.clients import RiotAPIClient

load_dotenv()

API_KEY = os.getenv('RIOTAPI')
MISTRAL_KEY = os.getenv('MISTRAL_KEY')
REGION = "na1"

# %%
async with RiotAPIClient(default_headers={"X-Riot-Token": API_KEY}) as client: 
    account = await client.get_account_v1_by_riot_id(region='americas',
                                                    game_name='LukePhysicist',
                                                    tag_line='NA1')
    matches = await client.get_lol_match_v5_match_ids_by_puuid(region='americas',
                                                               puuid=account['puuid'],
                                                               queries = {'start':0, 'count':15})
    league_match = await client.get_lol_match_v5_match(region='americas',
                                                 id=matches[0])
    match_timeline = await client.get_lol_match_v5_match_timeline(region='americas', id=matches[4])
print(json.dumps(account,indent=4))
print(json.dumps(matches,indent=4))
# Out:
# {
#     "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#     "gameName": "LukePhysicist",
#     "tagLine": "NA1"
# }
# [
#     "NA1_5223256507",
#     "NA1_5223227844",
#     "NA1_5223007331",
#     "NA1_5223000023",
#     "NA1_5222347760",
#     "NA1_5221714012",
#     "NA1_5220554885",
#     "NA1_5220527537",
#     "NA1_5220515974",
#     "NA1_5220475725",
#     "NA1_5220180563",
#     "NA1_5220156418",
#     "NA1_5220135361",
#     "NA1_5220113681",
#     "NA1_5219727342"
# ]

# %%
print(json.dumps(league_match,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5223256507",
#         "participants": [
#             "AOjnm_tk0zVM54wNyV2GTHxDhpL2JaQA6UG-SBA7yddFY1cKfrKY1sZl_x1zmEC-cMVC1Qeb05Zeug",
#             "YpD3ay4-l50sFo6XSXtdQM-Q9qKeW1RfqU7WIK9n1WLIjs8_keeUf6RBxxmL4H-jJflYxV8UscDQJQ",
#             "faWWY3pkCqwdRNR2OmzsIlubhzJsBhNcqrzW8QZ53xP5bvprB2jLW7Z3l43winZzFvXhZeHHP2csFw",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "Akq1mBdWlTjKKHhvCVSigzZ48er5lm-TufmwWFFmf7wCC82Jb4TQnSVFjMAlPggR-ykn9-5d2sBo7Q",
#             "ChuVeg_xfu4wZ7DUTMwJFnqY4_LmTvQAxYct2e4WEYFQ6l6XBBMua63rCScrBObR_O4mhO3N7-1oXg",
#             "2W4JqBdMnIkfsgpejhwT8FKWucWG9V4nt3i1S-KqHoJEXef2VsHj5bhWGqvTVHVhan22YGuhfn8QJw",
#             "XVXHFdJxu8fHTi2DX8oobhjaG4dUvv61m56SxiiijkH-chxEz9Gs-LgtpcHSz_x4py3YlbhcevfGOg",
#             "hZII9pxyy-PDjRsMFJMH0xRhOmyhXIzBy_eRFZppDmaz-Jybh6D7o5v_Tp-Cf61Y8CZFqF2R4A7TSQ",
#             "QnoXCluuULgXwfa2Pvw1I6uYwBlxQSlc29uNA14kj1hJEqI64b3Qp1UiDAk6OF9uBKcnDBHQv0ZAKg"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "gameCreation": 1738808144009,
#         "gameDuration": 1337,
#         "gameEndTimestamp": 1738809535048,
#         "gameId": 5223256507,
#         "gameMode": "CLASSIC",
#         "gameName": "teambuilder-match-5223256507",
#         "gameStartTimestamp": 1738808197326,
#         "gameType": "MATCHED_GAME",
#         "gameVersion": "15.3.654.407",
#         "mapId": 11,
#         "participants": [
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 1,
#                 "assists": 1,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 4,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 370,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 146,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 721.7737705623811,
#                     "damageTakenOnTeamPercentage": 0.19052170706262164,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 4,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 0,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1338.0487563870001,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 375.6549718905546,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 0,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 1.25,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.5,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 1,
#                     "killsNearEnemyTurret": 1,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 1,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 4,
#                     "laneMinionsFirst10Minutes": 63,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3124,
#                         3115
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 1,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 2,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 1,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 4,
#                     "skillshotsHit": 14,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 4,
#                     "stealthWardsPlaced": 3,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 5,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 4,
#                     "takedownsInAlcove": 1,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.3223528866690089,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 1,
#                     "turretTakedowns": 1,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.4238584041595459,
#                     "visionScorePerMinute": 0.550184899858684,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 0,
#                     "wardTakedownsBefore20M": 0,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 12081,
#                 "champLevel": 14,
#                 "championId": 10,
#                 "championName": "Kayle",
#                 "championTransform": 0,
#                 "commandPings": 5,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 2204,
#                 "damageDealtToObjectives": 2204,
#                 "damageDealtToTurrets": 2204,
#                 "damageSelfMitigated": 4917,
#                 "dangerPings": 0,
#                 "deaths": 4,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 2,
#                 "enemyVisionPings": 0,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": true,
#                 "getBackPings": 0,
#                 "goldEarned": 8377,
#                 "goldSpent": 7800,
#                 "holdPings": 0,
#                 "individualPosition": "TOP",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 0,
#                 "item0": 2031,
#                 "item1": 3124,
#                 "item2": 3115,
#                 "item3": 3006,
#                 "item4": 1055,
#                 "item5": 0,
#                 "item6": 3363,
#                 "itemsPurchased": 16,
#                 "killingSprees": 1,
#                 "kills": 4,
#                 "lane": "TOP",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 3,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 361,
#                 "magicDamageDealt": 52509,
#                 "magicDamageDealtToChampions": 8896,
#                 "magicDamageTaken": 10014,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 1,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 1,
#                 "participantId": 1,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5005
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8008,
#                                     "var1": 404,
#                                     "var2": 404,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9101,
#                                     "var1": 811,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9104,
#                                     "var1": 18,
#                                     "var2": 10,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8299,
#                                     "var1": 622,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8234,
#                                     "var1": 6508,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8236,
#                                     "var1": 24,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 41113,
#                 "physicalDamageDealtToChampions": 7199,
#                 "physicalDamageTaken": 5165,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6488,
#                 "pushPings": 0,
#                 "puuid": "AOjnm_tk0zVM54wNyV2GTHxDhpL2JaQA6UG-SBA7yddFY1cKfrKY1sZl_x1zmEC-cMVC1Qeb05Zeug",
#                 "quadraKills": 0,
#                 "retreatPings": 7,
#                 "riotIdGameName": "Northrend",
#                 "riotIdTagline": "wrath",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 33,
#                 "spell2Casts": 43,
#                 "spell3Casts": 65,
#                 "spell4Casts": 5,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 2,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 2,
#                 "summoner2Id": 12,
#                 "summonerId": "6gNM2OlWUiP8-bHguI2CzZyA29vkNwjiv3aVjOVgsagRDrNW",
#                 "summonerLevel": 78,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "TOP",
#                 "timeCCingOthers": 4,
#                 "timePlayed": 1337,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 93808,
#                 "totalDamageDealtToChampions": 16096,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 15724,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 4396,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 158,
#                 "totalTimeCCDealt": 107,
#                 "totalTimeSpentDead": 121,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 186,
#                 "trueDamageDealtToChampions": 0,
#                 "trueDamageTaken": 545,
#                 "turretKills": 1,
#                 "turretTakedowns": 1,
#                 "turretsLost": 4,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 12,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 0,
#                 "wardsPlaced": 7,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 2,
#                 "assists": 0,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 5,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 320,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 244,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 306.25010681152344,
#                     "buffsStolen": 7,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardTimeCoverageInRiverOrEnemyHalf": 0.4733739863525603,
#                     "controlWardsPlaced": 1,
#                     "damagePerMinute": 288.4315002080739,
#                     "damageTakenOnTeamPercentage": 0.29587304015303606,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 5,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 0,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 1,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 1,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1338.0487563870001,
#                     "goldPerMinute": 397.9283247029914,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 0,
#                     "initialBuffCount": 2,
#                     "initialCrabCount": 1,
#                     "jungleCsBefore10Minutes": 68.00000008940697,
#                     "junglerKillsEarlyJungle": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 1,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0.5,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 2,
#                     "killsOnLanersEarlyJungleAsJungler": 2,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 2,
#                     "laneMinionsFirst10Minutes": 1,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3142,
#                         6697,
#                         3142,
#                         3814
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 10.650000005960464,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 1,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 4,
#                     "skillshotsDodged": 6,
#                     "skillshotsHit": 13,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 4,
#                     "stealthWardsPlaced": 2,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 5,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 4,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.1288169929282706,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 0,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": 0.37599408626556396,
#                     "visionScorePerMinute": 1.0585627543124208,
#                     "voidMonsterKill": 3,
#                     "wardTakedowns": 6,
#                     "wardTakedownsBefore20M": 4,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 9823,
#                 "champLevel": 12,
#                 "championId": 121,
#                 "championName": "Khazix",
#                 "championTransform": 0,
#                 "commandPings": 1,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 0,
#                 "damageDealtToObjectives": 8033,
#                 "damageDealtToTurrets": 0,
#                 "damageSelfMitigated": 12357,
#                 "dangerPings": 0,
#                 "deaths": 5,
#                 "detectorWardsPlaced": 1,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 4,
#                 "enemyVisionPings": 0,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": true,
#                 "getBackPings": 0,
#                 "goldEarned": 8874,
#                 "goldSpent": 8637,
#                 "holdPings": 0,
#                 "individualPosition": "JUNGLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 0,
#                 "item0": 2020,
#                 "item1": 3142,
#                 "item2": 3814,
#                 "item3": 3158,
#                 "item4": 2055,
#                 "item5": 0,
#                 "item6": 3364,
#                 "itemsPurchased": 16,
#                 "killingSprees": 1,
#                 "kills": 5,
#                 "lane": "JUNGLE",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 2,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 389,
#                 "magicDamageDealt": 367,
#                 "magicDamageDealtToChampions": 367,
#                 "magicDamageTaken": 3758,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 1,
#                 "neutralMinionsKilled": 130,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 0,
#                 "participantId": 2,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5008,
#                         "offense": 5008
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8128,
#                                     "var1": 388,
#                                     "var2": 7,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8143,
#                                     "var1": 277,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8140,
#                                     "var1": 5,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8135,
#                                     "var1": 320,
#                                     "var2": 4,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8100
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8014,
#                                     "var1": 240,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 9111,
#                                     "var1": 207,
#                                     "var2": 100,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8000
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 106615,
#                 "physicalDamageDealtToChampions": 5694,
#                 "physicalDamageTaken": 18934,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 27,
#                 "pushPings": 0,
#                 "puuid": "YpD3ay4-l50sFo6XSXtdQM-Q9qKeW1RfqU7WIK9n1WLIjs8_keeUf6RBxxmL4H-jJflYxV8UscDQJQ",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "Juke0rAPCow",
#                 "riotIdTagline": "NA1",
#                 "role": "NONE",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 145,
#                 "spell2Casts": 68,
#                 "spell3Casts": 20,
#                 "spell4Casts": 11,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 2,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 11,
#                 "summoner2Id": 11,
#                 "summonerId": "PKe56KwDtsy9IpPrGELICMQCDPpW4HnAKbswVceGAgH_KKo",
#                 "summonerLevel": 90,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "JUNGLE",
#                 "timeCCingOthers": 3,
#                 "timePlayed": 1337,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 163942,
#                 "totalDamageDealtToChampions": 6432,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 24420,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 13688,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 17,
#                 "totalTimeCCDealt": 94,
#                 "totalTimeSpentDead": 107,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 56959,
#                 "trueDamageDealtToChampions": 370,
#                 "trueDamageTaken": 1726,
#                 "turretKills": 0,
#                 "turretTakedowns": 0,
#                 "turretsLost": 4,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 23,
#                 "visionWardsBoughtInGame": 2,
#                 "wardsKilled": 6,
#                 "wardsPlaced": 3,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 0,
#                 "assists": 0,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 0,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 235,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 568.128864860201,
#                     "damageTakenOnTeamPercentage": 0.1804924640320142,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 4,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 0,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
#                     "epicMonsterStolenWithoutSmite": 0,
#                     "firstTurretKilled": 0,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 0,
#                     "gameLength": 1338.0487563870001,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 301.7185282938486,
#                     "hadOpenNexus": 0,
#                     "immobilizeAndKillWithAlly": 0,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 0,
#                     "killAfterHiddenWithAlly": 0,
#                     "killParticipation": 0,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 0,
#                     "landSkillShotsEarlyGame": 2,
#                     "laneMinionsFirst10Minutes": 69,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         6655
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 12,
#                     "maxKillDeficit": 0,
#                     "maxLevelLeadLaneOpponent": 1,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 0,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 17,
#                     "skillshotsHit": 13,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "stealthWardsPlaced": 4,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 0,
#                     "takedownOnFirstTurret": 0,
#                     "takedowns": 0,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 0,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.253733215388221,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 0,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 0,
#                     "turretTakedowns": 1,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.28814083337783813,
#                     "visionScorePerMinute": 0.6795209189305067,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 4,
#                     "wardTakedownsBefore20M": 4,
#                     "wardsGuarded": 0
#                 },
#                 "champExperience": 10023,
#                 "champLevel": 13,
#                 "championId": 893,
#                 "championName": "Aurora",
#                 "championTransform": 0,
#                 "commandPings": 2,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 2380,
#                 "damageDealtToObjectives": 2380,
#                 "damageDealtToTurrets": 2380,
#                 "damageSelfMitigated": 5961,
#                 "dangerPings": 0,
#                 "deaths": 5,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 10,
#                 "enemyVisionPings": 0,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": true,
#                 "getBackPings": 0,
#                 "goldEarned": 6728,
#                 "goldSpent": 5700,
#                 "holdPings": 0,
#                 "individualPosition": "MIDDLE",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 0,
#                 "item0": 1056,
#                 "item1": 2031,
#                 "item2": 6655,
#                 "item3": 3020,
#                 "item4": 3145,
#                 "item5": 0,
#                 "item6": 3364,
#                 "itemsPurchased": 14,
#                 "killingSprees": 0,
#                 "kills": 0,
#                 "lane": "MIDDLE",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 0,
#                 "largestMultiKill": 0,
#                 "longestTimeSpentLiving": 456,
#                 "magicDamageDealt": 82920,
#                 "magicDamageDealtToChampions": 11657,
#                 "magicDamageTaken": 5675,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 1,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 1,
#                 "participantId": 3,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5011,
#                         "flex": 5008,
#                         "offense": 5008
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8229,
#                                     "var1": 1003,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8226,
#                                     "var1": 250,
#                                     "var2": 532,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8210,
#                                     "var1": 0,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8237,
#                                     "var1": 437,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8143,
#                                     "var1": 532,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8106,
#                                     "var1": 0,
#                                     "var2": 6,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8100
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 9946,
#                 "physicalDamageDealtToChampions": 480,
#                 "physicalDamageTaken": 7698,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 3840,
#                 "pushPings": 0,
#                 "puuid": "faWWY3pkCqwdRNR2OmzsIlubhzJsBhNcqrzW8QZ53xP5bvprB2jLW7Z3l43winZzFvXhZeHHP2csFw",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "\u02c9 w \u02c9",
#                 "riotIdTagline": "v  ",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 136,
#                 "spell2Casts": 15,
#                 "spell3Casts": 77,
#                 "spell4Casts": 7,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 1,
#                 "summoner1Id": 12,
#                 "summoner2Casts": 3,
#                 "summoner2Id": 4,
#                 "summonerId": "dbWUBdIkUJ_iefQa_KzGcEEmg9t0A3dHW-OIAnDArh3Gu_s",
#                 "summonerLevel": 221,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 100,
#                 "teamPosition": "MIDDLE",
#                 "timeCCingOthers": 5,
#                 "timePlayed": 1337,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 94325,
#                 "totalDamageDealtToChampions": 12669,
#                 "totalDamageShieldedOnTeammates": 0,
#                 "totalDamageTaken": 14897,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 1466,
#                 "totalHealsOnTeammates": 0,
#                 "totalMinionsKilled": 157,
#                 "totalTimeCCDealt": 215,
#                 "totalTimeSpentDead": 119,
#                 "totalUnitsHealed": 1,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 1458,
#                 "trueDamageDealtToChampions": 532,
#                 "trueDamageTaken": 1523,
#                 "turretKills": 1,
#                 "turretTakedowns": 1,
#                 "turretsLost": 4,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 15,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 4,
#                 "wardsPlaced": 4,
#                 "win": false
#             },
#             {
#                 "PlayerScore0": 0,
#                 "PlayerScore1": 0,
#                 "PlayerScore10": 0,
#                 "PlayerScore11": 0,
#                 "PlayerScore2": 0,
#                 "PlayerScore3": 0,
#                 "PlayerScore4": 0,
#                 "PlayerScore5": 0,
#                 "PlayerScore6": 0,
#                 "PlayerScore7": 0,
#                 "PlayerScore8": 0,
#                 "PlayerScore9": 0,
#                 "allInPings": 0,
#                 "assistMePings": 0,
#                 "assists": 0,
#                 "baronKills": 0,
#                 "basicPings": 0,
#                 "bountyLevel": 1,
#                 "challenges": {
#                     "12AssistStreakCount": 0,
#                     "HealFromMapSources": 0,
#                     "InfernalScalePickup": 0,
#                     "SWARM_DefeatAatrox": 0,
#                     "SWARM_DefeatBriar": 0,
#                     "SWARM_DefeatMiniBosses": 0,
#                     "SWARM_EvolveWeapon": 0,
#                     "SWARM_Have3Passives": 0,
#                     "SWARM_KillEnemy": 0,
#                     "SWARM_PickupGold": 0,
#                     "SWARM_ReachLevel50": 0,
#                     "SWARM_Survive15Min": 0,
#                     "SWARM_WinWith5EvolvedWeapons": 0,
#                     "abilityUses": 131,
#                     "acesBefore15Minutes": 0,
#                     "alliedJungleMonsterKills": 0,
#                     "baronTakedowns": 0,
#                     "blastConeOppositeOpponentCount": 0,
#                     "bountyGold": 0,
#                     "buffsStolen": 0,
#                     "completeSupportQuestInTime": 0,
#                     "controlWardsPlaced": 0,
#                     "damagePerMinute": 466.5331502927324,
#                     "damageTakenOnTeamPercentage": 0.14120809808748933,
#                     "dancedWithRiftHerald": 0,
#                     "deathsByEnemyChamps": 4,
#                     "dodgeSkillShotsSmallWindow": 0,
#                     "doubleAces": 0,
#                     "dragonTakedowns": 0,
#                     "earlyLaningPhaseGoldExpAdvantage": 0,
#                     "effectiveHealAndShielding": 0,
#                     "elderDragonKillsWithOpposingSoul": 0,
#                     "elderDragonMultikills": 0,
#                     "enemyChampionImmobilizations": 3,
#                     "enemyJungleMonsterKills": 0,
#                     "epicMonsterKillsNearEnemyJungler": 0,
#                     "epicMonsterKillsWithin30SecondsOfSpawn": 0,
#                     "epicMonsterSteals": 0,
# ...
#                     "firstTurretKilledTime": 847.7886335410001,
#                     "fistBumpParticipation": 0,
#                     "flawlessAces": 0,
#                     "fullTeamTakedown": 2,
#                     "gameLength": 1338.0487563870001,
#                     "getTakedownsInAllLanesEarlyJungleAsLaner": 0,
#                     "goldPerMinute": 271.88779864921037,
#                     "hadOpenNexus": 0,
#                     "highestCrowdControlScore": 1,
#                     "immobilizeAndKillWithAlly": 4,
#                     "initialBuffCount": 0,
#                     "initialCrabCount": 0,
#                     "jungleCsBefore10Minutes": 0,
#                     "junglerTakedownsNearDamagedEpicMonster": 0,
#                     "kTurretsDestroyedBeforePlatesFall": 0,
#                     "kda": 12,
#                     "killAfterHiddenWithAlly": 1,
#                     "killParticipation": 0.5217391304347826,
#                     "killedChampTookFullTeamDamageSurvived": 0,
#                     "killingSprees": 0,
#                     "killsNearEnemyTurret": 0,
#                     "killsOnOtherLanesEarlyJungleAsLaner": 0,
#                     "killsOnRecentlyHealedByAramPack": 0,
#                     "killsUnderOwnTurret": 0,
#                     "killsWithHelpFromEpicMonster": 0,
#                     "knockEnemyIntoTeamAndKill": 2,
#                     "landSkillShotsEarlyGame": 4,
#                     "laneMinionsFirst10Minutes": 4,
#                     "laningPhaseGoldExpAdvantage": 0,
#                     "legendaryCount": 0,
#                     "legendaryItemUsed": [
#                         3870,
#                         6617
#                     ],
#                     "lostAnInhibitor": 0,
#                     "maxCsAdvantageOnLaneOpponent": 0,
#                     "maxKillDeficit": 1,
#                     "maxLevelLeadLaneOpponent": 2,
#                     "mejaisFullStackInTime": 0,
#                     "moreEnemyJungleThanOpponent": 0,
#                     "multiKillOneSpell": 0,
#                     "multiTurretRiftHeraldCount": 0,
#                     "multikills": 0,
#                     "multikillsAfterAggressiveFlash": 0,
#                     "outerTurretExecutesBefore10Minutes": 0,
#                     "outnumberedKills": 0,
#                     "outnumberedNexusKill": 0,
#                     "perfectDragonSoulsTaken": 0,
#                     "perfectGame": 0,
#                     "pickKillWithAlly": 9,
#                     "playedChampSelectPosition": 1,
#                     "poroExplosions": 0,
#                     "quickCleanse": 0,
#                     "quickFirstTurret": 0,
#                     "quickSoloKills": 0,
#                     "riftHeraldTakedowns": 0,
#                     "saveAllyFromDeath": 0,
#                     "scuttleCrabKills": 0,
#                     "skillshotsDodged": 9,
#                     "skillshotsHit": 14,
#                     "snowballsHit": 0,
#                     "soloBaronKills": 0,
#                     "soloKills": 0,
#                     "stealthWardsPlaced": 17,
#                     "survivedSingleDigitHpCount": 0,
#                     "survivedThreeImmobilizesInFight": 2,
#                     "takedownOnFirstTurret": 1,
#                     "takedowns": 12,
#                     "takedownsAfterGainingLevelAdvantage": 0,
#                     "takedownsBeforeJungleMinionSpawn": 0,
#                     "takedownsFirstXMinutes": 3,
#                     "takedownsInAlcove": 0,
#                     "takedownsInEnemyFountain": 0,
#                     "teamBaronKills": 0,
#                     "teamDamagePercentage": 0.05426903802948314,
#                     "teamElderDragonKills": 0,
#                     "teamRiftHeraldKills": 1,
#                     "tookLargeDamageSurvived": 0,
#                     "turretPlatesTaken": 1,
#                     "turretTakedowns": 2,
#                     "turretsTakenWithRiftHerald": 0,
#                     "twentyMinionsIn3SecondsCount": 0,
#                     "twoWardsOneSweeperCount": 0,
#                     "unseenRecalls": 0,
#                     "visionScoreAdvantageLaneOpponent": -0.5836993455886841,
#                     "visionScorePerMinute": 1.0605240017463538,
#                     "voidMonsterKill": 0,
#                     "wardTakedowns": 2,
#                     "wardTakedownsBefore20M": 2,
#                     "wardsGuarded": 1
#                 },
#                 "champExperience": 8584,
#                 "champLevel": 12,
#                 "championId": 40,
#                 "championName": "Janna",
#                 "championTransform": 0,
#                 "commandPings": 6,
#                 "consumablesPurchased": 2,
#                 "damageDealtToBuildings": 1261,
#                 "damageDealtToObjectives": 2200,
#                 "damageDealtToTurrets": 1261,
#                 "damageSelfMitigated": 6421,
#                 "dangerPings": 0,
#                 "deaths": 1,
#                 "detectorWardsPlaced": 0,
#                 "doubleKills": 0,
#                 "dragonKills": 0,
#                 "eligibleForProgression": true,
#                 "enemyMissingPings": 0,
#                 "enemyVisionPings": 2,
#                 "firstBloodAssist": false,
#                 "firstBloodKill": false,
#                 "firstTowerAssist": false,
#                 "firstTowerKill": false,
#                 "gameEndedInEarlySurrender": false,
#                 "gameEndedInSurrender": true,
#                 "getBackPings": 0,
#                 "goldEarned": 6063,
#                 "goldSpent": 5300,
#                 "holdPings": 0,
#                 "individualPosition": "UTILITY",
#                 "inhibitorKills": 0,
#                 "inhibitorTakedowns": 0,
#                 "inhibitorsLost": 0,
#                 "item0": 3870,
#                 "item1": 6617,
#                 "item2": 3171,
#                 "item3": 1082,
#                 "item4": 3114,
#                 "item5": 0,
#                 "item6": 3364,
#                 "itemsPurchased": 14,
#                 "killingSprees": 0,
#                 "kills": 1,
#                 "lane": "BOTTOM",
#                 "largestCriticalStrike": 0,
#                 "largestKillingSpree": 0,
#                 "largestMultiKill": 1,
#                 "longestTimeSpentLiving": 631,
#                 "magicDamageDealt": 10900,
#                 "magicDamageDealtToChampions": 2685,
#                 "magicDamageTaken": 8463,
#                 "missions": {
#                     "playerScore0": 0,
#                     "playerScore1": 0,
#                     "playerScore2": 0,
#                     "playerScore3": 0,
#                     "playerScore4": 0,
#                     "playerScore5": 0,
#                     "playerScore6": 0,
#                     "playerScore7": 0,
#                     "playerScore8": 0,
#                     "playerScore9": 0,
#                     "playerScore10": 0,
#                     "playerScore11": 0
#                 },
#                 "needVisionPings": 0,
#                 "neutralMinionsKilled": 0,
#                 "nexusKills": 0,
#                 "nexusLost": 0,
#                 "nexusTakedowns": 0,
#                 "objectivesStolen": 0,
#                 "objectivesStolenAssists": 0,
#                 "onMyWayPings": 1,
#                 "participantId": 10,
#                 "pentaKills": 0,
#                 "perks": {
#                     "statPerks": {
#                         "defense": 5001,
#                         "flex": 5010,
#                         "offense": 5008
#                     },
#                     "styles": [
#                         {
#                             "description": "primaryStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8214,
#                                     "var1": 536,
#                                     "var2": 1044,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8226,
#                                     "var1": 250,
#                                     "var2": 296,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8234,
#                                     "var1": 9928,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8236,
#                                     "var1": 24,
#                                     "var2": 0,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8200
#                         },
#                         {
#                             "description": "subStyle",
#                             "selections": [
#                                 {
#                                     "perk": 8463,
#                                     "var1": 658,
#                                     "var2": 0,
#                                     "var3": 0
#                                 },
#                                 {
#                                     "perk": 8453,
#                                     "var1": 837,
#                                     "var2": 806,
#                                     "var3": 0
#                                 }
#                             ],
#                             "style": 8400
#                         }
#                     ]
#                 },
#                 "physicalDamageDealt": 3472,
#                 "physicalDamageDealtToChampions": 504,
#                 "physicalDamageTaken": 2423,
#                 "placement": 0,
#                 "playerAugment1": 0,
#                 "playerAugment2": 0,
#                 "playerAugment3": 0,
#                 "playerAugment4": 0,
#                 "playerAugment5": 0,
#                 "playerAugment6": 0,
#                 "playerSubteamId": 0,
#                 "profileIcon": 6422,
#                 "pushPings": 0,
#                 "puuid": "QnoXCluuULgXwfa2Pvw1I6uYwBlxQSlc29uNA14kj1hJEqI64b3Qp1UiDAk6OF9uBKcnDBHQv0ZAKg",
#                 "quadraKills": 0,
#                 "retreatPings": 0,
#                 "riotIdGameName": "MrQuestion52",
#                 "riotIdTagline": "Blade",
#                 "role": "SOLO",
#                 "sightWardsBoughtInGame": 0,
#                 "spell1Casts": 46,
#                 "spell2Casts": 28,
#                 "spell3Casts": 48,
#                 "spell4Casts": 4,
#                 "subteamPlacement": 0,
#                 "summoner1Casts": 3,
#                 "summoner1Id": 4,
#                 "summoner2Casts": 3,
#                 "summoner2Id": 7,
#                 "summonerId": "bs42asmlRYA-vQlmlrfWp3RI-EsEjDF2dI9ddVSzLwBpydw",
#                 "summonerLevel": 1135,
#                 "summonerName": "",
#                 "teamEarlySurrendered": false,
#                 "teamId": 200,
#                 "teamPosition": "UTILITY",
#                 "timeCCingOthers": 24,
#                 "timePlayed": 1337,
#                 "totalAllyJungleMinionsKilled": 0,
#                 "totalDamageDealt": 15560,
#                 "totalDamageDealtToChampions": 3190,
#                 "totalDamageShieldedOnTeammates": 5566,
#                 "totalDamageTaken": 11569,
#                 "totalEnemyJungleMinionsKilled": 0,
#                 "totalHeal": 5800,
#                 "totalHealsOnTeammates": 1418,
#                 "totalMinionsKilled": 11,
#                 "totalTimeCCDealt": 122,
#                 "totalTimeSpentDead": 16,
#                 "totalUnitsHealed": 5,
#                 "tripleKills": 0,
#                 "trueDamageDealt": 1186,
#                 "trueDamageDealtToChampions": 0,
#                 "trueDamageTaken": 682,
#                 "turretKills": 0,
#                 "turretTakedowns": 2,
#                 "turretsLost": 2,
#                 "unrealKills": 0,
#                 "visionClearedPings": 0,
#                 "visionScore": 23,
#                 "visionWardsBoughtInGame": 0,
#                 "wardsKilled": 2,
#                 "wardsPlaced": 17,
#                 "win": true
#             }
#         ],
#         "platformId": "NA1",
#         "queueId": 420,
#         "teams": [
#             {
#                 "bans": [
#                     {
#                         "championId": 223,
#                         "pickTurn": 1
#                     },
#                     {
#                         "championId": 141,
#                         "pickTurn": 2
#                     },
#                     {
#                         "championId": 143,
#                         "pickTurn": 3
#                     },
#                     {
#                         "championId": 84,
#                         "pickTurn": 4
#                     },
#                     {
#                         "championId": 29,
#                         "pickTurn": 5
#                     }
#                 ],
#                 "objectives": {
#                     "atakhan": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "baron": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "champion": {
#                         "first": false,
#                         "kills": 10
#                     },
#                     "dragon": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "horde": {
#                         "first": true,
#                         "kills": 3
#                     },
#                     "inhibitor": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "riftHerald": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "tower": {
#                         "first": false,
#                         "kills": 2
#                     }
#                 },
#                 "teamId": 100,
#                 "win": false
#             },
#             {
#                 "bans": [
#                     {
#                         "championId": 37,
#                         "pickTurn": 6
#                     },
#                     {
#                         "championId": 35,
#                         "pickTurn": 7
#                     },
#                     {
#                         "championId": 22,
#                         "pickTurn": 8
#                     },
#                     {
#                         "championId": 800,
#                         "pickTurn": 9
#                     },
#                     {
#                         "championId": 887,
#                         "pickTurn": 10
#                     }
#                 ],
#                 "objectives": {
#                     "atakhan": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "baron": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "champion": {
#                         "first": true,
#                         "kills": 24
#                     },
#                     "dragon": {
#                         "first": true,
#                         "kills": 3
#                     },
#                     "horde": {
#                         "first": false,
#                         "kills": 3
#                     },
#                     "inhibitor": {
#                         "first": false,
#                         "kills": 0
#                     },
#                     "riftHerald": {
#                         "first": true,
#                         "kills": 1
#                     },
#                     "tower": {
#                         "first": true,
#                         "kills": 4
#                     }
#                 },
#                 "teamId": 200,
#                 "win": true
#             }
#         ],
#         "tournamentCode": ""
#     }
# }

# %%
print(json.dumps(match_timeline,indent=4))
# Out:
# {
#     "metadata": {
#         "dataVersion": "2",
#         "matchId": "NA1_5222347760",
#         "participants": [
#             "A61bG74pZxB73RVdpGURIzEG43A5bqPE-HXPfuLJqZ9zRleFHsGkbfDYqKaKv8_hwByeIBKpccfIWg",
#             "INpLrQJP8Ko3XMMEHk1wF26nkVoXTCV8Kk5GO9bi0_xw-scSksDnD-6avTesKKHfLzaLLm7Y8aMvGw",
#             "ET18YWz4XnCMHLuk53V432LlFQ-m7Z7zBXTIN7yhylyQcgWWZJFu1mDX8uiKJyf1R5MRnH7CSM4Wjg",
#             "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA",
#             "SWbJs3Ywf0Tp5BjpgP5wqJVnxrpx15HFam4iNPU5O4v0uZGnyllG1iB0YERJVA8zkOhkMA5utKQ1lA",
#             "FXhRfWpjHKOWB1kDqUWAbxca7loPfA_Bwd2-CbwonJxv4bUH2vO-Flhns7XYkr2uSPiOScUzBz9Swg",
#             "rrbJzyvfGoQkjg2yHy1TGEM0lbPfdq0W5-XlwUzoQygJxswB_WfIKkkQTMDeU-2kR_GX25KiOHqDUg",
#             "yalSG3zuM0TBa6pKD6ruOtgwhbTUG_LDBEjyF6DIry-6z2v_dgi3gvgwpL1bN4b1RP3--_-ehbMDDg",
#             "LyiSYB2OGHEKWJP1yHZ5jjH46BEJX8VKSHtnR3On3X3NmT77dHTwMeWgEh989vKSJqEJ8yCVdm0zZw",
#             "AUZ-ghWkuupE5PvClbWjFgSTgoYhIkJyx9tl8JhrJLCfmmSp8mz5ejNk2K53oriVkoXYGX5V0LV_Fw"
#         ]
#     },
#     "info": {
#         "endOfGameResult": "GameComplete",
#         "frameInterval": 60000,
#         "frames": [
#             {
#                 "events": [
#                     {
#                         "realTimestamp": 1738695679638,
#                         "timestamp": 0,
#                         "type": "PAUSE_END"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 33,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 620,
#                             "healthMax": 620,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 280,
#                             "powerMax": 280,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 554,
#                             "y": 581
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 30,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 655,
#                             "healthMax": 655,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 295,
#                             "powerMax": 295,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 593,
#                             "y": 464
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 23,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 607,
#                             "healthMax": 607,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 475,
#                             "powerMax": 475,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 557,
#                             "y": 345
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 675,
#                             "healthMax": 675,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 361,
#                             "powerMax": 361,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 458,
#                             "y": 271
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 26,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 560,
#                             "healthMax": 560,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 365,
#                             "powerMax": 365,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 5,
#                         "position": {
#                             "x": 335,
#                             "y": 269
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 40,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 650,
#                             "healthMax": 650,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 28,
#                             "movementSpeed": 345,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 317,
#                             "powerMax": 317,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 6,
#                         "position": {
#                             "x": 14500,
#                             "y": 14511
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 33,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 685,
#                             "healthMax": 685,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 0,
#                             "powerMax": 0,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 7,
#                         "position": {
#                             "x": 14539,
#                             "y": 14394
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 21,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 590,
#                             "healthMax": 590,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 418,
#                             "powerMax": 418,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 8,
#                         "position": {
#                             "x": 14503,
#                             "y": 14275
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 27,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 580,
#                             "healthMax": 580,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 325,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 315,
#                             "powerMax": 315,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 9,
#                         "position": {
#                             "x": 14404,
#                             "y": 14201
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 21,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 25,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 580,
#                             "healthMax": 580,
#                             "healthRegen": 0,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 480,
#                             "powerMax": 480,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 500,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 10,
#                         "position": {
#                             "x": 14281,
#                             "y": 14199
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     }
#                 },
#                 "timestamp": 0
#             },
#             {
#                 "events": [
#                     {
#                         "itemId": 1056,
#                         "participantId": 3,
#                         "timestamp": 3932,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 3932,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 3,
#                         "timestamp": 3932,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 5,
#                         "timestamp": 4567,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 4567,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 5,
#                         "timestamp": 4567,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 5,
#                         "timestamp": 5101,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 4,
#                         "timestamp": 5101,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 4,
#                         "timestamp": 5101,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 4,
#                         "timestamp": 5435,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1103,
#                         "participantId": 7,
#                         "timestamp": 5535,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 1,
#                         "timestamp": 5569,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 1,
#                         "timestamp": 6070,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3364,
#                         "participantId": 7,
#                         "timestamp": 6137,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 3,
#                         "timestamp": 6437,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 2,
#                         "timestamp": 7206,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 7,
#                         "skillSlot": 2,
#                         "timestamp": 9143,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1056,
#                         "participantId": 8,
#                         "timestamp": 9477,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 8,
#                         "timestamp": 9477,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 8,
#                         "timestamp": 9477,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 8,
#                         "timestamp": 10279,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1055,
#                         "participantId": 9,
#                         "timestamp": 12517,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 9,
#                         "timestamp": 12517,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 9,
#                         "skillSlot": 1,
#                         "timestamp": 14454,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 3865,
#                         "participantId": 10,
#                         "timestamp": 15991,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 16392,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 10,
#                         "timestamp": 16559,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 10,
#                         "timestamp": 16726,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 4,
#                         "skillSlot": 1,
#                         "timestamp": 17260,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "itemId": 1102,
#                         "participantId": 2,
#                         "timestamp": 22905,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 1054,
#                         "participantId": 6,
#                         "timestamp": 28183,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 2003,
#                         "participantId": 6,
#                         "timestamp": 28183,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "itemId": 3340,
#                         "participantId": 6,
#                         "timestamp": 28584,
#                         "type": "ITEM_PURCHASED"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 8,
#                         "skillSlot": 2,
#                         "timestamp": 29051,
#                         "type": "SKILL_LEVEL_UP"
#                     },
#                     {
#                         "levelUpType": "NORMAL",
#                         "participantId": 1,
#                         "skillSlot": 1,
#                         "timestamp": 33160,
#                         "type": "SKILL_LEVEL_UP"
#                     }
#                 ],
#                 "participantFrames": {
#                     "1": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 33,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 75,
#                             "attackSpeed": 113,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 710,
#                             "healthMax": 710,
#                             "healthRegen": 8,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 280,
#                             "powerMax": 280,
#                             "powerRegen": 14,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 1,
#                         "position": {
#                             "x": 7751,
#                             "y": 11155
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "2": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 30,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 68,
#                             "attackSpeed": 113,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 665,
#                             "healthMax": 665,
#                             "healthRegen": 20,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 32,
#                             "movementSpeed": 340,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 295,
#                             "powerMax": 295,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 2,
#                         "position": {
#                             "x": 6266,
#                             "y": 9935
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "3": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 36,
#                             "armor": 23,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 53,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 762,
#                             "healthMax": 762,
#                             "healthRegen": 12,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 335,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 475,
#                             "powerMax": 475,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 3,
#                         "position": {
#                             "x": 7579,
#                             "y": 10016
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "4": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 29,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 79,
#                             "attackSpeed": 110,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 820,
#                             "healthMax": 820,
#                             "healthRegen": 7,
#                             "lifesteal": 3,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 361,
#                             "powerMax": 361,
#                             "powerRegen": 16,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 4,
#                         "position": {
#                             "x": 7711,
#                             "y": 9976
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "5": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 9,
#                             "armor": 26,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 48,
#                             "attackSpeed": 100,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 600,
#                             "healthMax": 600,
#                             "healthRegen": 12,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 30,
#                             "movementSpeed": 330,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 365,
#                             "powerMax": 365,
#                             "powerRegen": 28,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 0,
#                         "damageStats": {
#                             "magicDamageDone": 0,
#                             "magicDamageDoneToChampions": 0,
#                             "magicDamageTaken": 0,
#                             "physicalDamageDone": 0,
#                             "physicalDamageDoneToChampions": 0,
#                             "physicalDamageTaken": 0,
#                             "totalDamageDone": 0,
#                             "totalDamageDoneToChampions": 0,
#                             "totalDamageTaken": 0,
#                             "trueDamageDone": 0,
#                             "trueDamageDoneToChampions": 0,
#                             "trueDamageTaken": 0
#                         },
#                         "goldPerSecond": 30,
#                         "jungleMinionsKilled": 0,
#                         "level": 1,
#                         "minionsKilled": 0,
#                         "participantId": 5,
#                         "position": {
#                             "x": 8251,
#                             "y": 10208
#                         },
#                         "timeEnemySpentControlled": 0,
#                         "totalGold": 500,
#                         "xp": 0
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 40,
#                             "armorPen": 0,
# ...
#                             "physicalDamageDone": 4744,
#                             "physicalDamageDoneToChampions": 211,
#                             "physicalDamageTaken": 9666,
#                             "totalDamageDone": 25802,
#                             "totalDamageDoneToChampions": 6309,
#                             "totalDamageTaken": 31290,
#                             "trueDamageDone": 4898,
#                             "trueDamageDoneToChampions": 779,
#                             "trueDamageTaken": 1727
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 0,
#                         "level": 16,
#                         "minionsKilled": 38,
#                         "participantId": 5,
#                         "position": {
#                             "x": 8822,
#                             "y": 12881
#                         },
#                         "timeEnemySpentControlled": 202952,
#                         "totalGold": 10648,
#                         "xp": 15556
#                     },
#                     "6": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 199,
#                             "armorPen": 0,
#                             "armorPenPercent": 30,
#                             "attackDamage": 350,
#                             "attackSpeed": 168,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 3305,
#                             "healthMax": 4219,
#                             "healthRegen": 34,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 62,
#                             "movementSpeed": 390,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 780,
#                             "powerMax": 844,
#                             "powerRegen": 30,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 2757,
#                         "damageStats": {
#                             "magicDamageDone": 7179,
#                             "magicDamageDoneToChampions": 2892,
#                             "magicDamageTaken": 19619,
#                             "physicalDamageDone": 219036,
#                             "physicalDamageDoneToChampions": 43463,
#                             "physicalDamageTaken": 24679,
#                             "totalDamageDone": 238642,
#                             "totalDamageDoneToChampions": 49142,
#                             "totalDamageTaken": 53464,
#                             "trueDamageDone": 12427,
#                             "trueDamageDoneToChampions": 2785,
#                             "trueDamageTaken": 9166
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 4,
#                         "level": 18,
#                         "minionsKilled": 229,
#                         "participantId": 6,
#                         "position": {
#                             "x": 1926,
#                             "y": 1800
#                         },
#                         "timeEnemySpentControlled": 116008,
#                         "totalGold": 18837,
#                         "xp": 22017
#                     },
#                     "7": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 155,
#                             "armor": 279,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 117,
#                             "attackSpeed": 127,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 3169,
#                             "healthMax": 4218,
#                             "healthRegen": 27,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 128,
#                             "movementSpeed": 385,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 0,
#                             "powerMax": 0,
#                             "powerRegen": 0,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1529,
#                         "damageStats": {
#                             "magicDamageDone": 254882,
#                             "magicDamageDoneToChampions": 33577,
#                             "magicDamageTaken": 16439,
#                             "physicalDamageDone": 35575,
#                             "physicalDamageDoneToChampions": 876,
#                             "physicalDamageTaken": 44810,
#                             "totalDamageDone": 407202,
#                             "totalDamageDoneToChampions": 35532,
#                             "totalDamageTaken": 66593,
#                             "trueDamageDone": 116747,
#                             "trueDamageDoneToChampions": 1077,
#                             "trueDamageTaken": 5344
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 234,
#                         "level": 18,
#                         "minionsKilled": 56,
#                         "participantId": 7,
#                         "position": {
#                             "x": 2014,
#                             "y": 1970
#                         },
#                         "timeEnemySpentControlled": 725688,
#                         "totalGold": 17902,
#                         "xp": 24326
#                     },
#                     "8": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 578,
#                             "armor": 150,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 104,
#                             "attackSpeed": 147,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 2538,
#                             "healthMax": 2538,
#                             "healthRegen": 25,
#                             "lifesteal": 0,
#                             "magicPen": 0,
#                             "magicPenPercent": 13,
#                             "magicResist": 52,
#                             "movementSpeed": 375,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 1612,
#                             "powerMax": 1693,
#                             "powerRegen": 43,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1150,
#                         "damageStats": {
#                             "magicDamageDone": 125751,
#                             "magicDamageDoneToChampions": 22340,
#                             "magicDamageTaken": 16410,
#                             "physicalDamageDone": 15274,
#                             "physicalDamageDoneToChampions": 939,
#                             "physicalDamageTaken": 11799,
#                             "totalDamageDone": 209312,
#                             "totalDamageDoneToChampions": 30861,
#                             "totalDamageTaken": 29672,
#                             "trueDamageDone": 68285,
#                             "trueDamageDoneToChampions": 7581,
#                             "trueDamageTaken": 1462
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 0,
#                         "level": 18,
#                         "minionsKilled": 255,
#                         "participantId": 8,
#                         "position": {
#                             "x": 2875,
#                             "y": 3212
#                         },
#                         "timeEnemySpentControlled": 125844,
#                         "totalGold": 16034,
#                         "xp": 21932
#                     },
#                     "9": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 0,
#                             "armor": 106,
#                             "armorPen": 0,
#                             "armorPenPercent": 39,
#                             "attackDamage": 400,
#                             "attackSpeed": 238,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 2664,
#                             "healthMax": 2664,
#                             "healthRegen": 25,
#                             "lifesteal": 5,
#                             "magicPen": 0,
#                             "magicPenPercent": 0,
#                             "magicResist": 52,
#                             "movementSpeed": 384,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 964,
#                             "powerMax": 995,
#                             "powerRegen": 38,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 3032,
#                         "damageStats": {
#                             "magicDamageDone": 2134,
#                             "magicDamageDoneToChampions": 1150,
#                             "magicDamageTaken": 15909,
#                             "physicalDamageDone": 249703,
#                             "physicalDamageDoneToChampions": 30257,
#                             "physicalDamageTaken": 10499,
#                             "totalDamageDone": 254927,
#                             "totalDamageDoneToChampions": 31924,
#                             "totalDamageTaken": 27130,
#                             "trueDamageDone": 3089,
#                             "trueDamageDoneToChampions": 517,
#                             "trueDamageTaken": 721
#                         },
#                         "goldPerSecond": 0,
#                         "jungleMinionsKilled": 4,
#                         "level": 18,
#                         "minionsKilled": 288,
#                         "participantId": 9,
#                         "position": {
#                             "x": 2011,
#                             "y": 1557
#                         },
#                         "timeEnemySpentControlled": 122158,
#                         "totalGold": 18126,
#                         "xp": 20140
#                     },
#                     "10": {
#                         "championStats": {
#                             "abilityHaste": 0,
#                             "abilityPower": 399,
#                             "armor": 96,
#                             "armorPen": 0,
#                             "armorPenPercent": 0,
#                             "attackDamage": 101,
#                             "attackSpeed": 143,
#                             "bonusArmorPenPercent": 0,
#                             "bonusMagicPenPercent": 0,
#                             "ccReduction": 0,
#                             "cooldownReduction": 0,
#                             "health": 2723,
#                             "healthMax": 2723,
#                             "healthRegen": 47,
#                             "lifesteal": 0,
#                             "magicPen": 27,
#                             "magicPenPercent": 0,
#                             "magicResist": 48,
#                             "movementSpeed": 375,
#                             "omnivamp": 0,
#                             "physicalVamp": 0,
#                             "power": 1420,
#                             "powerMax": 1420,
#                             "powerRegen": 65,
#                             "spellVamp": 0
#                         },
#                         "currentGold": 1267,
#                         "damageStats": {
#                             "magicDamageDone": 65430,
#                             "magicDamageDoneToChampions": 20043,
#                             "magicDamageTaken": 6578,
#                             "physicalDamageDone": 5257,
#                             "physicalDamageDoneToChampions": 856,
#                             "physicalDamageTaken": 10990,
#                             "totalDamageDone": 73203,
#                             "totalDamageDoneToChampions": 21743,
#                             "totalDamageTaken": 17692,
#                             "trueDamageDone": 2515,
#                             "trueDamageDoneToChampions": 843,
#                             "trueDamageTaken": 123
#                         },
#                         "goldPerSecond": 50,
#                         "jungleMinionsKilled": 0,
#                         "level": 16,
#                         "minionsKilled": 60,
#                         "participantId": 10,
#                         "position": {
#                             "x": 2300,
#                             "y": 2175
#                         },
#                         "timeEnemySpentControlled": 197134,
#                         "totalGold": 12386,
#                         "xp": 15382
#                     }
#                 },
#                 "timestamp": 2465605
#             }
#         ],
#         "gameId": 5222347760,
#         "participants": [
#             {
#                 "participantId": 1,
#                 "puuid": "A61bG74pZxB73RVdpGURIzEG43A5bqPE-HXPfuLJqZ9zRleFHsGkbfDYqKaKv8_hwByeIBKpccfIWg"
#             },
#             {
#                 "participantId": 2,
#                 "puuid": "INpLrQJP8Ko3XMMEHk1wF26nkVoXTCV8Kk5GO9bi0_xw-scSksDnD-6avTesKKHfLzaLLm7Y8aMvGw"
#             },
#             {
#                 "participantId": 3,
#                 "puuid": "ET18YWz4XnCMHLuk53V432LlFQ-m7Z7zBXTIN7yhylyQcgWWZJFu1mDX8uiKJyf1R5MRnH7CSM4Wjg"
#             },
#             {
#                 "participantId": 4,
#                 "puuid": "jq88NuZS4IVeusaJSyTKzeu_qTYBQJ5ClwswSpPCCrkEbsJiG0gMd4pupOAiJeLaKu7sDi-DfommdA"
#             },
#             {
#                 "participantId": 5,
#                 "puuid": "SWbJs3Ywf0Tp5BjpgP5wqJVnxrpx15HFam4iNPU5O4v0uZGnyllG1iB0YERJVA8zkOhkMA5utKQ1lA"
#             },
#             {
#                 "participantId": 6,
#                 "puuid": "FXhRfWpjHKOWB1kDqUWAbxca7loPfA_Bwd2-CbwonJxv4bUH2vO-Flhns7XYkr2uSPiOScUzBz9Swg"
#             },
#             {
#                 "participantId": 7,
#                 "puuid": "rrbJzyvfGoQkjg2yHy1TGEM0lbPfdq0W5-XlwUzoQygJxswB_WfIKkkQTMDeU-2kR_GX25KiOHqDUg"
#             },
#             {
#                 "participantId": 8,
#                 "puuid": "yalSG3zuM0TBa6pKD6ruOtgwhbTUG_LDBEjyF6DIry-6z2v_dgi3gvgwpL1bN4b1RP3--_-ehbMDDg"
#             },
#             {
#                 "participantId": 9,
#                 "puuid": "LyiSYB2OGHEKWJP1yHZ5jjH46BEJX8VKSHtnR3On3X3NmT77dHTwMeWgEh989vKSJqEJ8yCVdm0zZw"
#             },
#             {
#                 "participantId": 10,
#                 "puuid": "AUZ-ghWkuupE5PvClbWjFgSTgoYhIkJyx9tl8JhrJLCfmmSp8mz5ejNk2K53oriVkoXYGX5V0LV_Fw"
#             }
#         ]
#     }
# }

# %%
# blue = 12.2
# red = 11
import json
import grab as gb
with open('test.json', 'r') as file:
    snapshot = json.load(file)

intra_minute = {
            "kill_diff": 0,
            "gold_diff": 150,
            "allied_lvl_ups": 3,
            "enemy_lvl_ups": 1,
        }
team = 100
gb.avg_distance_to_fountain(snapshot, 100)
# Out:
# np.float64(14235.902285966707)

# %%
from grab import seconds_till
seconds_till(2465605, 0)
# Out:
# 2465.605
